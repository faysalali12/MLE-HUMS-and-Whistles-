# %% [markdown]
# # ECS7020P mini-project submission
#
# The mini-project consists of two components:
#
#
# 1.   **Basic solution** [6 marks]: Using the MLEnd Hums and Whistles dataset, build a machine learning pipeline that takes as an input a Potter or a StarWars audio segment and predicts its song label (either Harry or StarWars).
# 2.   **Advanced solution** [10 marks]: There are two options. (i) Formulate a machine learning problem that can be attempted using the MLEnd Hums and Whistles dataset and build a solution model. (ii) Create a product that uses the functionality provided by a model trained on the MLEnd Hums and Whistles dataset (e.g. a simple App that predicts the label Harry or StarWars when you hum to it).
#
# The submission will consist of two Jupyter notebooks, one for the basic solution and another one for advanced solution. Please **name each notebook**:
#
# * ECS7020P_miniproject_basic.ipynb
# * ECS7020P_miniproject_advanced.ipynb
#
# then **zipped and submitted toghether**.
#
# Each uploaded notebook should consist of:
#
# *   **Text cells**, describing concisely each step and results.
# *   **Code cells**, implementing each step.
# *   **Output cells**, i.e. the output from each code cell.
#
# and **should have the structure** indicated below. Notebooks will not be run, please make sure that the output cells are saved.
#
# How will we evaluate your submission?
#
# *   Conciseness in your writing (10%).
# *   Correctness in your methodology (30%).
# *   Correctness in your analysis and conclusions (30%).
# *   Completeness (10%).
# *   Originality (10%).
# *   Efforts to try something new (10%).
#
# Suggestion: Why don't you use **GitHub** to manage your project? GitHub can be used as a presentation card that showcases what you have done and gives evidence of your data science skills, knowledge and experience.
#
# Each notebook should be structured into the following 9 sections:

# %% [markdown]
# # 1 Author
#
# **Student Name**:  Faysal Ali
# **Student ID**:  180135787

# %% [markdown]
# # 2 Problem formulation
#
# **Describe the machine learning problem that you want to solve and explain what's interesting about it.**
#
#
# In this Mini-project, the MLEnds Hums and Whistles dataset was used to predict the label of a song from the an audio file that contained either a hum or whistle. The two sets of files used for the basic solution of this project contained a small section of audio from the theme songs of Harry Potter and Starwars. The interesting part of this machine learning problem was the use of certain features in the audio file that allowed the model to easily distinguish what theme song the audio file belonged to.

# %% [markdown]
# # 3 Machine Learning pipeline
#
# **Describe your ML pipeline. Clearly identify its input and output, any intermediate stages (for instance, transformation -> models), and intermediate data moving from one stage to the next. Note that your pipeline does not need to include all the stages.**
#
# The Machine learning pipeline that was used for this project consisted of using the inputs (Hum and Whistle audio files for Harry Potter and StarWars) and classifying the song label as Potter or StarWars as the output. In order for the model to function without any errors or have data missing, the raw data was cleaned and the file names were corrected. The dataset that was used was part 1 folders for both Potter and StarWars. The overall dataset that was used for this model included 416 audio files. Each of the files followed a certain structure when it came to file_id and Interpretation number, which allowed a dataframe to be created using the audio files. The dataframe created was used to extract the information that was required by the model.

# %% [markdown]
# # 4 Transformation stage
#
# **Describe any transformations, such as feature extraction. Identify input and output.**
#
# The feature extraction that was used for this machine learning problem was Pitch. The pitch was used to distinguish between the different audio files that correspond to specific song labels.Since the audio file contained a large number of dimensions, using the pitch as the feature extraction allowed it to be reduced to 5 dimension:
# 1.   Power.
# 2.   Pitch mean.
# 3.   Pitch standard deviation.
# 4.   Fraction of voiced region.
#
# These 5 features were then used as predictors.

# %% [markdown]
# # 5 Modelling
#
# **Describe the ML models that you will implement.**
#
# A support vector machine (SVM) model was used to predict and distinguish whether the audio file was Showman or Mamma. The dataset was then split into a training set and a validation set, with the accuracy of the training and validation sets compared.

# %% [markdown]
# # 6 Methodology
#
# **Describe how you will train and validate your models, how model performance is assesssed (i.e. accuracy, confusion matrix, etc)**
#
# In order to train the SVM model a classifier is created and used to class the data. The SVM model takes two arrays as an input: an array X of the shape holding the training set and array y holding the class labels. The classes are then predicted using the test set, with the training set and validation set accuracies then compared.

# %% [markdown]
# # 7 Dataset
#
# Describe the dataset that you will use to create your models and validate them. If you need to preprocess it, do it here. Include visualisations too. You can visualise raw data samples or extracted features.

# %%
from google.colab import drive

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import os, sys, re, pickle, glob
import urllib.request
import zipfile

import IPython.display as ipd
from tqdm import tqdm
import librosa

drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
def download_url(url, save_path):
    with urllib.request.urlopen(url) as dl_file:
        with open(save_path, 'wb') as out_file:
            out_file.write(dl_file.read())

# %%
path = '/content/drive/MyDrive/Data/Potter_1'
os.listdir(path)
# Out:
# ['S77_whistle_2_Potter.wav',
#  'S36_hum_1_Potter.wav',
#  'S54_hum_2_Potter.wav',
#  'S35_hum_1_[Potter].wav',
#  'S31_hum_2_Potter.wav',
#  'S53_hum_1_Potter.wav',
#  'S114_hum_2_potter.wav',
#  'S93_hum_2_Potter.wav',
#  'S17_hum_1_Potter.wav',
#  'S94_hum_1_Potter.wav',
#  'S72_whistle_2_Potter.wav',
#  'S22_hum_1_Potter.wav',
#  'S87_hum_2_Potter.wav',
#  'S7_hum_1_Potter.wav',
#  'S100_hum_2_Potter.wav',
#  'S2_whistle_2_Potter.wav',
#  'S58_hum_1_Potter.wav',
#  'S45_whistle_2_Potter.wav',
#  'S75_hum_2_Potter.wav',
#  'S99_whistle_1_[Potter].wav',
#  'S25_hum_2_Potter.wav',
#  'S40_whistle_2_potter.wav',
#  'S39_whistle_2_Potter.wav',
#  'S40_hum_2_potter.wav',
#  'S26_hum_1_Potter.wav',
#  'S60_whistle_1_[Potter].wav',
#  'S52_whistle_2_Potter.wav',
#  'S44_hum_2_Potter.wav',
#  'S47_hum_1_potter.wav',
#  'S78_whistle_2_Potter.wav',
#  'S8_hum_1_[Potter].wav',
#  'S62_hum_1_Potter.wav',
#  'S79_hum_4_[Potter].wav',
#  'S84_hum_1_Potter.wav',
#  'S4_hum_2_Potter.wav',
#  'S57_whistle_2_Potter.wav',
#  'S103_whistle_2_Potter.wav',
#  'S21_hum_2_Potter.wav',
#  'S71_hum_2_Potter.wav',
#  'S110_hum_2_Potter.wav',
#  'S97_hum_2_Potter.wav',
#  'S93_whistle_2_Potter.wav',
#  'S3_hum_1_Potter.wav',
#  'S104_Hum_2_Potter.wav',
#  'S65_hum_2_Potter.wav',
#  'S16_whistle_2_Potter.wav',
#  'S69_hum_1_Potter.wav',
#  'S24_whistle_2_Potter.wav',
#  'S50_hum_2_Potter.wav',
#  'S82_hum_4_[Potter].wav',
#  'S38_hum_3_Potterwav.wav',
#  'S13_hum_1_Potter.wav',
#  'S49_hum_4_[potter].wav',
#  'S96_whistle_1_[Potter].wav',
#  'S92_Hum_2_Potter.wav',
#  'S74_hum_2_Potter.wav',
#  'S115_hum_2_Potter.wav',
#  'S88_hum_1_[potter].wav',
#  'S6_whistle_2_Potter.wav',
#  'S30_hum_2_Potter.wav',
#  'S44_whistle_2_Potter.wav',
#  'S55_harrypotter_hum_2.wav',
#  'S73_hum_1_Potter.wav',
#  'S28_hum_1_Potter.wav',
#  'S101_hum_2_Potter.wav',
#  'S86_hum_2_Potter.wav',
#  'S23_hum_1_Potter.wav',
#  'S41_hum_2_Potter.wav',
#  'S76_whistle_2_Potter.wav',
#  'S109_hum_1_[Potter].wav',
#  'S24_hum_2_Potter.wav',
#  'S46_hum_1_Potter.wav',
#  'S42_Hum2_Potter.wav.Wav',
#  'S64_hum_2_Potter.wav',
#  'S60_hum_1_[Potter].wav',
#  'S80_whistle_2_Potter.wav',
#  'S1_hum_2_Potter.wav',
#  'S59_hum_1_Potter.wav',
#  'S106_hum_1_Potter.WAV',
#  'S61_whistle_1_[Potter].wav',
#  'S32_whistle_2_Potter.wav',
#  'S63_hum_1_[Potter].wav',
#  'S64_whistle_2_Potter.wav',
#  'S19_hum_1_Potter.wav',
#  'S38_hum_1_Potter.wav .wav',
#  'S108_whistle_2_Potter.wav',
#  'S20_hum_2_Potter.wav',
#  'S85_hum_1_Potter.wav',
#  'S5_hum_2_Potter.wav',
#  'S18_Whistle_2_Potter.wav',
#  'S92_Whistle_2_Potter.wav',
#  'S107_whistle_2_Potter.wav',
#  'S9_hum_1_Potter.wav',
#  'S89_hum_2_Potter.wav',
#  'S42_Hum3_Potter.wav.Wav',
#  'S51_hum_2_Potter.wav',
#  'S34_hum_2_Potter.wav',
#  'S45_hum_2_Potter.wav',
#  'S95_Whistle 2 Potter.wav',
#  'S96_hum_1_[Potter].wav',
#  'S55_harrypotter_whistle_1.wav',
#  'S56_whistle_2_Potter.wav',
#  'S102_whistle_2_Potter.wav',
#  'S15_hum_2_Potter.wav',
#  'S70_hum_2_Potter.wav',
#  'S111_hum_2_Potter.wav',
#  'S2_hum_2_Potter.wav',
#  'S68_whistle_2_Potter.wav',
#  'S102_hum_2_Potter.wav',
#  'S5_hum_1_Potter.wav',
#  'S85_hum_2_Potter.wav',
#  'S61_hum_1_[Potter].wav',
#  'S20_hum_1_Potter.wav',
#  'S19_hum_2_Potter.wav',
#  'S9_hum_2_Potter.wav',
#  'S67_whistle_2_Potter.wav',
#  'S111_hum_1_Potter.wav',
#  'S70_hum_1_Potter.wav',
#  'S91_hum_2_Potter.wav',
#  'S77_hum_2_Potter.wav',
#  'S29_whistle_2_potter.wav',
#  'S50_whistle_2_Potter.wav',
#  'S30_hum_1_Potter.wav',
#  'S37_whistle_1_[Potter].wav',
#  'S48_Whistle_2_Potter.wav',
#  'S68_hum_2_Potter.wav',
#  'S56_hum_2_Potter.wav',
#  'S91_whistle_2_Potter.wav',
#  'S10_hum_1_Potter .wav',
#  'S51_hum_1_Potter.wav',
#  'S99_hum_1_[Potter].wav',
#  'S74_hum_1_Potter.wav',
#  'S75_whistle_2_Potter.wav',
#  'S34_whistle_2_Potter.wav',
#  'S73_hum_2_Potter.wav',
#  'S12_hum_2_Potter .wav',
#  'S52_hum_2_Potter.wav',
#  'S67_hum_2_Potter.wav',
#  'S106_hum_2_Potter.WAV',
#  'S89_whistle_2_Potter.wav',
#  'S16_hum_2_Potter.wav',
#  'S28_hum_2_Potter.wav',
#  'S78_hum_2_Potter.wav',
#  'S23_hum_2_Potter.wav',
#  'S41_hum_1_Potter.wav',
#  'S105_hum_1_harry potter.wav',
#  'S6_hum_2_Potter.wav',
#  'S86_hum_1_Potter.wav',
#  'S101_hum_1_Potter.wav',
#  'S59_hum_2_Potter.wav',
#  'S103_hum_2_Potter.wav',
#  'S65_hum_1_Potter.wav',
#  'S104_Hum_1_Potter.wav',
#  'S3_hum_2_Potter.wav',
#  'S39_hum_2_Potter.wav',
#  'S66_whistle_2_Potter.wav',
#  'S63_hum_4_[Potter].wav',
#  'S46_hum_2_Potter.wav',
#  'S90_whistle_2_Potter.wav',
#  'S21_hum_1_Potter.wav',
#  'S8_hum_4_[Potter].wav',
#  'S43_hum_2_Potter.wav',
#  'S4_hum_1_Potter.wav',
#  'S84_hum_2_Potter.wav',
#  'S62_hum_2_Potter.wav',
#  'S57_hum_2_Potter.wav',
#  'S49_hum_1_[potter].wav',
#  'S82_hum_1_[Potter].wav',
#  'S79_hum_1_[Potter].wav',
#  'S26_hum_2_Potter.wav',
#  'S18_Hum_2_Potter.wav',
#  'S15_whistle_2_Potter.wav',
#  'S109_whistle_1_[Potter].wav',
#  'S32_hum_2_Potter.wav',
#  'S54_whistle_2_Potter.wav',
#  'S108_hum_2_Potter.wav',
#  'S69_hum_2_Potter.wav',
#  'S90_hum_2_Potter.wav',
#  'S37_hum_1_[Potter].wav',
#  'S13_hum_2_Potter.wav',
#  'S97_hum_1_Potter.wav',
#  'S110_hum_1_Potter.wav',
#  'S71_hum_1_Potter.wav',
#  'S114_hum_1_potter.wav',
#  'S43_whistle_2_Potter.wav',
#  'S17_hum_2_Potter.wav',
#  'S29_hum_2_Potter.wav',
#  'S88_whistle_1_[potter].wav',
#  'S76_hum_2_Potter.wav',
#  'S48_Hum_2_Potter.wav',
#  'S35_hum_4_[Potter].wav',
#  'S31_hum_1_Potter.wav',
#  'S1_whistle_2_Potter.wav',
#  'S95_Hum 2 Potter.wav',
#  'S53_hum_2_Potter.wav',
#  'S72_hum_2_Potter.wav',
#  'S94_hum_2_Potter.wav',
#  'S10_hum_2_Potter .wav',
#  'S100_hum_1_Potter.wav',
#  'S7_hum_2_Potter.wav',
#  'S22_hum_2_Potter.wav',
#  'S47_hum_2_potter.wav',
#  'S25_hum_1_Potter.wav',
#  'S36_hum_2_Potter.wav',
#  'S12_hum_4_Potter .wav',
#  'S80_hum_2_Potter.wav',
#  'S58_hum_2_Potter.wav',
#  'S66_hum_2_Potter.wav',
#  'S107_hum_2_Potter.wav',
#  'S87_whistle_2_Potter.wav']

# %%
sample_path = '/content/drive/MyDrive/Data/Potter_1/*.wav'
files_potter = glob.glob(sample_path)
len(files_potter)
for _ in range(5):
  n = np.random.randint(210)
  display(ipd.Audio(files[n]))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
pot_table = [] 

for file in files_potter:
  file_name = file.split('/')[-1]
  participant_ID = file.split('/')[-1].split('_')[0]
  interpretation_type = file.split('/')[-1].split('_')[1]
  #interpretation_number = file.split('/')[-1].split('_')[2]
  #song = file.split('/')[-1].split('_')[3].split('.')[0]
  pot_table.append([file_name,participant_ID,interpretation_type,interpretation_number, song])

pot_table
# Out:
# [['S77_whistle_2_Potter.wav', 'S77', 'whistle', '2', 'Potter'],
#  ['S36_hum_1_Potter.wav', 'S36', 'hum', '2', 'Potter'],
#  ['S54_hum_2_Potter.wav', 'S54', 'hum', '2', 'Potter'],
#  ['S35_hum_1_[Potter].wav', 'S35', 'hum', '2', 'Potter'],
#  ['S31_hum_2_Potter.wav', 'S31', 'hum', '2', 'Potter'],
#  ['S53_hum_1_Potter.wav', 'S53', 'hum', '2', 'Potter'],
#  ['S114_hum_2_potter.wav', 'S114', 'hum', '2', 'Potter'],
#  ['S93_hum_2_Potter.wav', 'S93', 'hum', '2', 'Potter'],
#  ['S17_hum_1_Potter.wav', 'S17', 'hum', '2', 'Potter'],
#  ['S94_hum_1_Potter.wav', 'S94', 'hum', '2', 'Potter'],
#  ['S72_whistle_2_Potter.wav', 'S72', 'whistle', '2', 'Potter'],
#  ['S22_hum_1_Potter.wav', 'S22', 'hum', '2', 'Potter'],
#  ['S87_hum_2_Potter.wav', 'S87', 'hum', '2', 'Potter'],
#  ['S7_hum_1_Potter.wav', 'S7', 'hum', '2', 'Potter'],
#  ['S100_hum_2_Potter.wav', 'S100', 'hum', '2', 'Potter'],
#  ['S2_whistle_2_Potter.wav', 'S2', 'whistle', '2', 'Potter'],
#  ['S58_hum_1_Potter.wav', 'S58', 'hum', '2', 'Potter'],
#  ['S45_whistle_2_Potter.wav', 'S45', 'whistle', '2', 'Potter'],
#  ['S75_hum_2_Potter.wav', 'S75', 'hum', '2', 'Potter'],
#  ['S99_whistle_1_[Potter].wav', 'S99', 'whistle', '2', 'Potter'],
#  ['S25_hum_2_Potter.wav', 'S25', 'hum', '2', 'Potter'],
#  ['S40_whistle_2_potter.wav', 'S40', 'whistle', '2', 'Potter'],
#  ['S39_whistle_2_Potter.wav', 'S39', 'whistle', '2', 'Potter'],
#  ['S40_hum_2_potter.wav', 'S40', 'hum', '2', 'Potter'],
#  ['S26_hum_1_Potter.wav', 'S26', 'hum', '2', 'Potter'],
#  ['S60_whistle_1_[Potter].wav', 'S60', 'whistle', '2', 'Potter'],
#  ['S52_whistle_2_Potter.wav', 'S52', 'whistle', '2', 'Potter'],
#  ['S44_hum_2_Potter.wav', 'S44', 'hum', '2', 'Potter'],
#  ['S47_hum_1_potter.wav', 'S47', 'hum', '2', 'Potter'],
#  ['S78_whistle_2_Potter.wav', 'S78', 'whistle', '2', 'Potter'],
#  ['S8_hum_1_[Potter].wav', 'S8', 'hum', '2', 'Potter'],
#  ['S62_hum_1_Potter.wav', 'S62', 'hum', '2', 'Potter'],
#  ['S79_hum_4_[Potter].wav', 'S79', 'hum', '2', 'Potter'],
#  ['S84_hum_1_Potter.wav', 'S84', 'hum', '2', 'Potter'],
#  ['S4_hum_2_Potter.wav', 'S4', 'hum', '2', 'Potter'],
#  ['S57_whistle_2_Potter.wav', 'S57', 'whistle', '2', 'Potter'],
#  ['S103_whistle_2_Potter.wav', 'S103', 'whistle', '2', 'Potter'],
#  ['S21_hum_2_Potter.wav', 'S21', 'hum', '2', 'Potter'],
#  ['S71_hum_2_Potter.wav', 'S71', 'hum', '2', 'Potter'],
#  ['S110_hum_2_Potter.wav', 'S110', 'hum', '2', 'Potter'],
#  ['S97_hum_2_Potter.wav', 'S97', 'hum', '2', 'Potter'],
#  ['S93_whistle_2_Potter.wav', 'S93', 'whistle', '2', 'Potter'],
#  ['S3_hum_1_Potter.wav', 'S3', 'hum', '2', 'Potter'],
#  ['S104_Hum_2_Potter.wav', 'S104', 'Hum', '2', 'Potter'],
#  ['S65_hum_2_Potter.wav', 'S65', 'hum', '2', 'Potter'],
#  ['S16_whistle_2_Potter.wav', 'S16', 'whistle', '2', 'Potter'],
#  ['S69_hum_1_Potter.wav', 'S69', 'hum', '2', 'Potter'],
#  ['S24_whistle_2_Potter.wav', 'S24', 'whistle', '2', 'Potter'],
#  ['S50_hum_2_Potter.wav', 'S50', 'hum', '2', 'Potter'],
#  ['S82_hum_4_[Potter].wav', 'S82', 'hum', '2', 'Potter'],
#  ['S38_hum_3_Potterwav.wav', 'S38', 'hum', '2', 'Potter'],
#  ['S13_hum_1_Potter.wav', 'S13', 'hum', '2', 'Potter'],
#  ['S49_hum_4_[potter].wav', 'S49', 'hum', '2', 'Potter'],
#  ['S96_whistle_1_[Potter].wav', 'S96', 'whistle', '2', 'Potter'],
#  ['S92_Hum_2_Potter.wav', 'S92', 'Hum', '2', 'Potter'],
#  ['S74_hum_2_Potter.wav', 'S74', 'hum', '2', 'Potter'],
#  ['S115_hum_2_Potter.wav', 'S115', 'hum', '2', 'Potter'],
#  ['S88_hum_1_[potter].wav', 'S88', 'hum', '2', 'Potter'],
#  ['S6_whistle_2_Potter.wav', 'S6', 'whistle', '2', 'Potter'],
#  ['S30_hum_2_Potter.wav', 'S30', 'hum', '2', 'Potter'],
#  ['S44_whistle_2_Potter.wav', 'S44', 'whistle', '2', 'Potter'],
#  ['S55_harrypotter_hum_2.wav', 'S55', 'harrypotter', '2', 'Potter'],
#  ['S73_hum_1_Potter.wav', 'S73', 'hum', '2', 'Potter'],
#  ['S28_hum_1_Potter.wav', 'S28', 'hum', '2', 'Potter'],
#  ['S101_hum_2_Potter.wav', 'S101', 'hum', '2', 'Potter'],
#  ['S86_hum_2_Potter.wav', 'S86', 'hum', '2', 'Potter'],
#  ['S23_hum_1_Potter.wav', 'S23', 'hum', '2', 'Potter'],
#  ['S41_hum_2_Potter.wav', 'S41', 'hum', '2', 'Potter'],
#  ['S76_whistle_2_Potter.wav', 'S76', 'whistle', '2', 'Potter'],
#  ['S109_hum_1_[Potter].wav', 'S109', 'hum', '2', 'Potter'],
#  ['S24_hum_2_Potter.wav', 'S24', 'hum', '2', 'Potter'],
#  ['S46_hum_1_Potter.wav', 'S46', 'hum', '2', 'Potter'],
#  ['S64_hum_2_Potter.wav', 'S64', 'hum', '2', 'Potter'],
#  ['S60_hum_1_[Potter].wav', 'S60', 'hum', '2', 'Potter'],
#  ['S80_whistle_2_Potter.wav', 'S80', 'whistle', '2', 'Potter'],
#  ['S1_hum_2_Potter.wav', 'S1', 'hum', '2', 'Potter'],
#  ['S59_hum_1_Potter.wav', 'S59', 'hum', '2', 'Potter'],
#  ['S61_whistle_1_[Potter].wav', 'S61', 'whistle', '2', 'Potter'],
#  ['S32_whistle_2_Potter.wav', 'S32', 'whistle', '2', 'Potter'],
#  ['S63_hum_1_[Potter].wav', 'S63', 'hum', '2', 'Potter'],
#  ['S64_whistle_2_Potter.wav', 'S64', 'whistle', '2', 'Potter'],
#  ['S19_hum_1_Potter.wav', 'S19', 'hum', '2', 'Potter'],
#  ['S38_hum_1_Potter.wav .wav', 'S38', 'hum', '2', 'Potter'],
#  ['S108_whistle_2_Potter.wav', 'S108', 'whistle', '2', 'Potter'],
#  ['S20_hum_2_Potter.wav', 'S20', 'hum', '2', 'Potter'],
#  ['S85_hum_1_Potter.wav', 'S85', 'hum', '2', 'Potter'],
#  ['S5_hum_2_Potter.wav', 'S5', 'hum', '2', 'Potter'],
#  ['S18_Whistle_2_Potter.wav', 'S18', 'Whistle', '2', 'Potter'],
#  ['S92_Whistle_2_Potter.wav', 'S92', 'Whistle', '2', 'Potter'],
#  ['S107_whistle_2_Potter.wav', 'S107', 'whistle', '2', 'Potter'],
#  ['S9_hum_1_Potter.wav', 'S9', 'hum', '2', 'Potter'],
#  ['S89_hum_2_Potter.wav', 'S89', 'hum', '2', 'Potter'],
#  ['S51_hum_2_Potter.wav', 'S51', 'hum', '2', 'Potter'],
#  ['S34_hum_2_Potter.wav', 'S34', 'hum', '2', 'Potter'],
#  ['S45_hum_2_Potter.wav', 'S45', 'hum', '2', 'Potter'],
#  ['S95_Whistle 2 Potter.wav', 'S95', 'Whistle 2 Potter.wav', '2', 'Potter'],
#  ['S96_hum_1_[Potter].wav', 'S96', 'hum', '2', 'Potter'],
#  ['S55_harrypotter_whistle_1.wav', 'S55', 'harrypotter', '2', 'Potter'],
#  ['S56_whistle_2_Potter.wav', 'S56', 'whistle', '2', 'Potter'],
#  ['S102_whistle_2_Potter.wav', 'S102', 'whistle', '2', 'Potter'],
#  ['S15_hum_2_Potter.wav', 'S15', 'hum', '2', 'Potter'],
#  ['S70_hum_2_Potter.wav', 'S70', 'hum', '2', 'Potter'],
#  ['S111_hum_2_Potter.wav', 'S111', 'hum', '2', 'Potter'],
#  ['S2_hum_2_Potter.wav', 'S2', 'hum', '2', 'Potter'],
#  ['S68_whistle_2_Potter.wav', 'S68', 'whistle', '2', 'Potter'],
#  ['S102_hum_2_Potter.wav', 'S102', 'hum', '2', 'Potter'],
#  ['S5_hum_1_Potter.wav', 'S5', 'hum', '2', 'Potter'],
#  ['S85_hum_2_Potter.wav', 'S85', 'hum', '2', 'Potter'],
#  ['S61_hum_1_[Potter].wav', 'S61', 'hum', '2', 'Potter'],
#  ['S20_hum_1_Potter.wav', 'S20', 'hum', '2', 'Potter'],
#  ['S19_hum_2_Potter.wav', 'S19', 'hum', '2', 'Potter'],
#  ['S9_hum_2_Potter.wav', 'S9', 'hum', '2', 'Potter'],
#  ['S67_whistle_2_Potter.wav', 'S67', 'whistle', '2', 'Potter'],
#  ['S111_hum_1_Potter.wav', 'S111', 'hum', '2', 'Potter'],
#  ['S70_hum_1_Potter.wav', 'S70', 'hum', '2', 'Potter'],
#  ['S91_hum_2_Potter.wav', 'S91', 'hum', '2', 'Potter'],
#  ['S77_hum_2_Potter.wav', 'S77', 'hum', '2', 'Potter'],
#  ['S29_whistle_2_potter.wav', 'S29', 'whistle', '2', 'Potter'],
#  ['S50_whistle_2_Potter.wav', 'S50', 'whistle', '2', 'Potter'],
#  ['S30_hum_1_Potter.wav', 'S30', 'hum', '2', 'Potter'],
#  ['S37_whistle_1_[Potter].wav', 'S37', 'whistle', '2', 'Potter'],
#  ['S48_Whistle_2_Potter.wav', 'S48', 'Whistle', '2', 'Potter'],
#  ['S68_hum_2_Potter.wav', 'S68', 'hum', '2', 'Potter'],
#  ['S56_hum_2_Potter.wav', 'S56', 'hum', '2', 'Potter'],
#  ['S91_whistle_2_Potter.wav', 'S91', 'whistle', '2', 'Potter'],
#  ['S10_hum_1_Potter .wav', 'S10', 'hum', '2', 'Potter'],
#  ['S51_hum_1_Potter.wav', 'S51', 'hum', '2', 'Potter'],
#  ['S99_hum_1_[Potter].wav', 'S99', 'hum', '2', 'Potter'],
#  ['S74_hum_1_Potter.wav', 'S74', 'hum', '2', 'Potter'],
#  ['S75_whistle_2_Potter.wav', 'S75', 'whistle', '2', 'Potter'],
#  ['S34_whistle_2_Potter.wav', 'S34', 'whistle', '2', 'Potter'],
#  ['S73_hum_2_Potter.wav', 'S73', 'hum', '2', 'Potter'],
#  ['S12_hum_2_Potter .wav', 'S12', 'hum', '2', 'Potter'],
#  ['S52_hum_2_Potter.wav', 'S52', 'hum', '2', 'Potter'],
#  ['S67_hum_2_Potter.wav', 'S67', 'hum', '2', 'Potter'],
#  ['S89_whistle_2_Potter.wav', 'S89', 'whistle', '2', 'Potter'],
#  ['S16_hum_2_Potter.wav', 'S16', 'hum', '2', 'Potter'],
#  ['S28_hum_2_Potter.wav', 'S28', 'hum', '2', 'Potter'],
#  ['S78_hum_2_Potter.wav', 'S78', 'hum', '2', 'Potter'],
#  ['S23_hum_2_Potter.wav', 'S23', 'hum', '2', 'Potter'],
#  ['S41_hum_1_Potter.wav', 'S41', 'hum', '2', 'Potter'],
#  ['S105_hum_1_harry potter.wav', 'S105', 'hum', '2', 'Potter'],
#  ['S6_hum_2_Potter.wav', 'S6', 'hum', '2', 'Potter'],
#  ['S86_hum_1_Potter.wav', 'S86', 'hum', '2', 'Potter'],
#  ['S101_hum_1_Potter.wav', 'S101', 'hum', '2', 'Potter'],
#  ['S59_hum_2_Potter.wav', 'S59', 'hum', '2', 'Potter'],
#  ['S103_hum_2_Potter.wav', 'S103', 'hum', '2', 'Potter'],
#  ['S65_hum_1_Potter.wav', 'S65', 'hum', '2', 'Potter'],
#  ['S104_Hum_1_Potter.wav', 'S104', 'Hum', '2', 'Potter'],
#  ['S3_hum_2_Potter.wav', 'S3', 'hum', '2', 'Potter'],
#  ['S39_hum_2_Potter.wav', 'S39', 'hum', '2', 'Potter'],
#  ['S66_whistle_2_Potter.wav', 'S66', 'whistle', '2', 'Potter'],
#  ['S63_hum_4_[Potter].wav', 'S63', 'hum', '2', 'Potter'],
#  ['S46_hum_2_Potter.wav', 'S46', 'hum', '2', 'Potter'],
#  ['S90_whistle_2_Potter.wav', 'S90', 'whistle', '2', 'Potter'],
#  ['S21_hum_1_Potter.wav', 'S21', 'hum', '2', 'Potter'],
#  ['S8_hum_4_[Potter].wav', 'S8', 'hum', '2', 'Potter'],
#  ['S43_hum_2_Potter.wav', 'S43', 'hum', '2', 'Potter'],
#  ['S4_hum_1_Potter.wav', 'S4', 'hum', '2', 'Potter'],
#  ['S84_hum_2_Potter.wav', 'S84', 'hum', '2', 'Potter'],
#  ['S62_hum_2_Potter.wav', 'S62', 'hum', '2', 'Potter'],
#  ['S57_hum_2_Potter.wav', 'S57', 'hum', '2', 'Potter'],
#  ['S49_hum_1_[potter].wav', 'S49', 'hum', '2', 'Potter'],
#  ['S82_hum_1_[Potter].wav', 'S82', 'hum', '2', 'Potter'],
#  ['S79_hum_1_[Potter].wav', 'S79', 'hum', '2', 'Potter'],
#  ['S26_hum_2_Potter.wav', 'S26', 'hum', '2', 'Potter'],
#  ['S18_Hum_2_Potter.wav', 'S18', 'Hum', '2', 'Potter'],
#  ['S15_whistle_2_Potter.wav', 'S15', 'whistle', '2', 'Potter'],
#  ['S109_whistle_1_[Potter].wav', 'S109', 'whistle', '2', 'Potter'],
#  ['S32_hum_2_Potter.wav', 'S32', 'hum', '2', 'Potter'],
#  ['S54_whistle_2_Potter.wav', 'S54', 'whistle', '2', 'Potter'],
#  ['S108_hum_2_Potter.wav', 'S108', 'hum', '2', 'Potter'],
#  ['S69_hum_2_Potter.wav', 'S69', 'hum', '2', 'Potter'],
#  ['S90_hum_2_Potter.wav', 'S90', 'hum', '2', 'Potter'],
#  ['S37_hum_1_[Potter].wav', 'S37', 'hum', '2', 'Potter'],
#  ['S13_hum_2_Potter.wav', 'S13', 'hum', '2', 'Potter'],
#  ['S97_hum_1_Potter.wav', 'S97', 'hum', '2', 'Potter'],
#  ['S110_hum_1_Potter.wav', 'S110', 'hum', '2', 'Potter'],
#  ['S71_hum_1_Potter.wav', 'S71', 'hum', '2', 'Potter'],
#  ['S114_hum_1_potter.wav', 'S114', 'hum', '2', 'Potter'],
#  ['S43_whistle_2_Potter.wav', 'S43', 'whistle', '2', 'Potter'],
#  ['S17_hum_2_Potter.wav', 'S17', 'hum', '2', 'Potter'],
#  ['S29_hum_2_Potter.wav', 'S29', 'hum', '2', 'Potter'],
#  ['S88_whistle_1_[potter].wav', 'S88', 'whistle', '2', 'Potter'],
#  ['S76_hum_2_Potter.wav', 'S76', 'hum', '2', 'Potter'],
#  ['S48_Hum_2_Potter.wav', 'S48', 'Hum', '2', 'Potter'],
#  ['S35_hum_4_[Potter].wav', 'S35', 'hum', '2', 'Potter'],
#  ['S31_hum_1_Potter.wav', 'S31', 'hum', '2', 'Potter'],
#  ['S1_whistle_2_Potter.wav', 'S1', 'whistle', '2', 'Potter'],
#  ['S95_Hum 2 Potter.wav', 'S95', 'Hum 2 Potter.wav', '2', 'Potter'],
#  ['S53_hum_2_Potter.wav', 'S53', 'hum', '2', 'Potter'],
#  ['S72_hum_2_Potter.wav', 'S72', 'hum', '2', 'Potter'],
#  ['S94_hum_2_Potter.wav', 'S94', 'hum', '2', 'Potter'],
#  ['S10_hum_2_Potter .wav', 'S10', 'hum', '2', 'Potter'],
#  ['S100_hum_1_Potter.wav', 'S100', 'hum', '2', 'Potter'],
#  ['S7_hum_2_Potter.wav', 'S7', 'hum', '2', 'Potter'],
#  ['S22_hum_2_Potter.wav', 'S22', 'hum', '2', 'Potter'],
#  ['S47_hum_2_potter.wav', 'S47', 'hum', '2', 'Potter'],
#  ['S25_hum_1_Potter.wav', 'S25', 'hum', '2', 'Potter'],
#  ['S36_hum_2_Potter.wav', 'S36', 'hum', '2', 'Potter'],
#  ['S12_hum_4_Potter .wav', 'S12', 'hum', '2', 'Potter'],
#  ['S80_hum_2_Potter.wav', 'S80', 'hum', '2', 'Potter'],
#  ['S58_hum_2_Potter.wav', 'S58', 'hum', '2', 'Potter'],
#  ['S66_hum_2_Potter.wav', 'S66', 'hum', '2', 'Potter'],
#  ['S107_hum_2_Potter.wav', 'S107', 'hum', '2', 'Potter'],
#  ['S87_whistle_2_Potter.wav', 'S87', 'whistle', '2', 'Potter']]

# %%
potter_df = pd.DataFrame(pot_table,columns=['file_id','participant','interpretation','number','song']).set_index('file_id') 
potter_df
# Out:
#                          participant interpretation number    song
# file_id
# S77_whistle_2_Potter.wav         S77        whistle      2  Potter
# S36_hum_1_Potter.wav             S36            hum      2  Potter
# S54_hum_2_Potter.wav             S54            hum      2  Potter
# S35_hum_1_[Potter].wav           S35            hum      2  Potter
# S31_hum_2_Potter.wav             S31            hum      2  Potter
# ...                              ...            ...    ...     ...
# S80_hum_2_Potter.wav             S80            hum      2  Potter
# S58_hum_2_Potter.wav             S58            hum      2  Potter
# S66_hum_2_Potter.wav             S66            hum      2  Potter
# S107_hum_2_Potter.wav           S107            hum      2  Potter
# S87_whistle_2_Potter.wav         S87        whistle      2  Potter
#
# [206 rows x 4 columns]

# %%
path1 = '/content/drive/MyDrive/Data/StarWars_1'
os.listdir(path1)
# Out:
# ['S86_hum_3_StarWars.wav',
#  'S23_hum_4_StarWars.wav',
#  'S86_hum_4_StarWars.wav',
#  'S23_hum_3_StarWars.wav',
#  'S61_hum_1_StarWars.wav',
#  'S2_whistle_2_StarWars.wav',
#  'S43_hum_2_StarWars.wav',
#  'S66_whistle_2_StarWars.wav',
#  'S88_hum_2_StarWars.wav',
#  'S91_whistle_2_StarWars.wav',
#  'S50_whistle_2_StarWars.wav',
#  'S104_hum_3_StarWars.wav',
#  'S50_hum_2_StarWars.wav',
#  'S70_hum_4_StarWars.wav',
#  'S13_hum_4_StarWars.wav',
#  'S57_whistle_2_StarWars.wav',
#  'S70_hum_3_StarWars.wav',
#  'S13_hum_3_StarWars.wav',
#  'S73_hum_3_StarWars.wav',
#  'S10_hum_3_StarWars.wav',
#  'S73_hum_4_StarWars.wav',
#  'S10_hum_4_StarWars.wav',
#  'S109_hum_3_StarWars.wav',
#  'S96_hum_2_StarWars.wav',
#  'S104_hum_4_StarWars.wav',
#  'S1_whistle_2_StarWars.wav',
#  'S109_hum_4_StarWars.wav',
#  'S3_hum_3_StarWars.wav',
#  'S63_hum_3_StarWars.wav',
#  'S40_hum_2_StarWars.wav',
#  'S114_hum_3_StarWars.wav',
#  'S54_whistle_2_StarWars.wav',
#  'S114_hum_4_StarWars.wav',
#  'S30_hum_4_StarWars.wav',
#  'S6_whistle_2_StarWars.wav',
#  'S53_hum_3_StarWars.wav',
#  'S107_hum_2_StarWars.wav',
#  'S30_hum_3_StarWars.wav',
#  'S68_whistle_2_StarWars.wav',
#  'S3_hum_4_StarWars.wav',
#  'S63_hum_4_StarWars.wav',
#  'S18_hum_2_StarWars.wav',
#  'S99_hum_1_StarWars.wav',
#  'S60_hum_2_StarWars.wav',
#  'S102_whistle_1_StarWars.wav',
#  'S20_hum_3_StarWars.wav',
#  'S85_hum_4_StarWars.wav',
#  'S20_hum_4_StarWars.wav',
#  'S85_hum_3_StarWars.wav',
#  'S53_hum_4_StarWars.wav',
#  'S58_hum_3_StarWars.wav',
#  'S36_hum_3_StarWars.wav',
#  'S52_whistle_2_StarWars.wav',
#  'S58_hum_4_StarWars.wav',
#  'S93_whistle_2_StarWars.wav',
#  'S76_hum_2_StarWars.wav',
#  'S15_hum_2_StarWars.wav',
#  'S55_whistle_2_StarWars.wav',
#  'S94_whistle_2_StarWars.wav',
#  'S26_hum_3_StarWars.wav',
#  'S26_hum_4_StarWars.wav',
#  'S37_hum_1_StarWars.wav',
#  'S66_hum_2_StarWars.wav',
#  'S16_whistle_2_StarWars.wav',
#  'S36_hum_4_StarWars.wav',
#  'S64_whistle_2_StarWars.wav',
#  'S65_hum_4_StarWars.wav',
#  'S8_hum_3_StarWars.wav',
#  'S5_hum_4_StarWars.wav',
#  'S65_hum_3_StarWars.wav',
#  'S8_hum_4_StarWars.wav',
#  'S5_hum_3_StarWars.wav',
#  'S90_hum_2_StarWars.wav',
#  'S56_hum_2_StarWars.wav',
#  'S18_whistle_2_StarWars.wav',
#  'S111_hum_4_StarWars.wav',
#  'S48_hum_2_StarWars.wav',
#  'S29_whistle_2_StarWars.wav',
#  'S111_hum_3_StarWars.wav',
#  'S45_hum_2_StarWars.wav',
#  'S56_whistle_2_StarWars.wav',
#  'S80_hum_2_StarWars.wav',
#  'S28_hum_4_StarWars.wav',
#  'S90_whistle_2_StarWars.wav',
#  'S24_whistle_2_StarWars.wav',
#  'S68_hum_2_StarWars.wav',
#  'S101_hum_3_StarWars.wav',
#  'S67_whistle_2_StarWars.wav',
#  'S93_hum_2_StarWars.wav',
#  'S101_hum_4_StarWars.wav',
#  'S78_hum_2_StarWars.wav',
#  'S75_hum_2_StarWars.wav',
#  'S16_hum_2_StarWars.wav',
#  'S46_hum_4_StarWars.wav',
#  'S25_hum_4_StarWars.wav',
#  'S28_hum_3_StarWars.wav',
#  'S46_hum_3_StarWars.wav',
#  'S25_hum_3_StarWars.wav',
#  'S19_hum_4_StarWars.wav',
#  'S35_hum_3_StarWars.wav',
#  'S38_hum_4_StarWars.wav',
#  'S15_whistle_2_StarWars.wav',
#  'S35_hum_4_StarWars.wav',
#  'S38_hum_3_StarWars.wav',
#  'S43_whistle_2_StarWars.wav',
#  'S54_hum_2_StarWars.wav',
#  'S100_hum_4_StarWars.wav',
#  'S92_hum_2_StarWars.wav',
#  'S19_hum_3_StarWars.wav',
#  'S7_hum_4_StarWars.wav',
#  'S72_whistle_2_StarWars.wav',
#  'S37_hum_2_StarWars.wav',
#  'S100_hum_3_StarWars.wav',
#  'S78_whistle_2_StarWars.wav',
#  'S103_whistle_2_StarWars.wav',
#  'S44_hum_2_StarWars.wav',
#  'S110_hum_3_StarWars.wav',
#  'S7_hum_3_StarWars.wav',
#  'S64_hum_2_StarWars.wav',
#  'S75_whistle_2_StarWars.wav',
#  'S44_whistle_2_StarWars.wav',
#  'S103_hum_2_StarWars.wav',
#  'S49_hum_2_StarWars.wav',
#  'S110_hum_4_StarWars.wav',
#  'S67_hum_2_StarWars.wav',
#  'S47_hum_4_StarWars.wav',
#  'S47_hum_3_StarWars.wav',
#  'S77_hum_2_StarWars.wav',
#  'S82_hum_4_StarWars.wav',
#  'S82_hum_3_StarWars.wav',
#  'S49_hum_3_StarWars.wav',
#  'S32_whistle_2_StarWars.wav',
#  'S55_hum_1_StarWars.wav',
#  'S40_whistle_2_StarWars.wav',
#  'S69_hum_4_StarWars.wav',
#  'S59_hum_3_StarWars.wav',
#  'S76_whistle_2_Starwars.wav',
#  'S92_hum_3_StarWars.wav',
#  'S59_hum_4_StarWars.wav',
#  'S107_whistle_2_StarWars.wav',
#  'S29_hum_2_StarWars.wav',
#  'S4_hum_4_StarWars.wav',
#  'S9_hum_3_StarWars.wav',
#  'S69_hum_3_StarWars.wav',
#  'S4_hum_3_StarWars.wav',
#  'S9_hum_4_StarWars.wav',
#  'S74_hum_3_StarWars.wav',
#  'S79_hum_4_StarWars.wav',
#  'S17_hum_3_StarWars.wav',
#  'S74_hum_4_StarWars.wav',
#  'S79_hum_3_StarWars.wav',
#  'S17_hum_4_StarWars.wav',
#  'S24_hum_2_StarWars.wav',
#  'S62_hum_4_StarWars.wav',
#  'S62_hum_3_StarWars.wav',
#  'S87_hum_2_StarWars.wav',
#  'S39_hum_2_StarWars.wav',
#  'S91_hum_2_StarWars.wav',
#  'S34_hum_2_StarWars.wav',
#  'S57_hum_2_StarWars.wav',
#  'S42_hum_3_StarWars.wav',
#  'S84_hum_4_StarWars.wav',
#  'S21_hum_3_StarWars.wav',
#  'S84_hum_3_StarWars.wav',
#  'S21_hum_4_StarWars.wav',
#  'S34_whistle_2_StarWars.wav',
#  'S80_whistle_2_StarWars.wav',
#  'S32_hum_2_StarWars.wav',
#  'S87_whistle_2_StarWars.wav',
#  'S31_hum_4_StarWars.wav',
#  'S31_hum_3_StarWars.wav',
#  'S39_whistle_2_StarWars.wav',
#  'S1_hum_2_StarWars.wav',
#  'S95_hum_1_StarWars.wav',
#  'S61_hum_2_StarWars.wav',
#  'S77_whistle_2_StarWars.wav',
#  'S97_hum_4_StarWars.wav',
#  'S51_hum_3_StarWars.wav',
#  'S97_hum_3_StarWars.wav',
#  'S108_hum_2_StarWars.wav',
#  'S105_whistle_2_StarWars.wav',
#  'S51_hum_4_StarWars.wav',
#  'S88_hum_1_StarWars.wav',
#  'S45_whistle_2_StarWars.wav',
#  'S22_hum_4_StarWars.wav',
#  'S41_hum_3_StarWars.wav',
#  'S22_hum_3_StarWars.wav',
#  'S115_hum_2_StarWars.wav',
#  'S72_hum_2_StarWars.wav',
#  'S95_whistle_1_StarWars.wav',
#  'S102_whistle_2_StarWars.wav',
#  'S106_hum_4_StarWars.WAV',
#  'S96_hum_1_StarWars.wav',
#  'S2_hum_2_StarWars.wav',
#  'S41_hum_4_StarWars.wav',
#  'S52_hum_2_StarWars.wav',
#  'S99_hum_2_StarWars.wav',
#  'S106_hum_3_StarWars.WAV',
#  'S60_hum_1_StarWars.wav',
#  'S94_hum_2_StarWars.wav',
#  'S89_hum_2_StarWars.wav',
#  'S42_hum_2_StarWars.wav',
#  'S12_hum_4_StarWars.wav',
#  'S71_hum_4_StarWars.wav',
#  'S108_whistle_2_StarWars.wav',
#  'S12_hum_3_StarWars.wav',
#  'S71_hum_3_StarWars.wav',
#  'S6_whistle_1_StarWars.wav',
#  'S48_whistle_2_StarWars.wav',
#  'S89_whistle_2_StarWars.wav']

# %%
sample_path1 = '/content/drive/MyDrive/Data/StarWars_1/*.wav'
files_starwars = glob.glob(sample_path1)
len(files_starwars)
# Out:
# 208

# %%
star_table = [] 

for file in files_starwars:
  file_name = file.split('/')[-1]
  participant_ID = file.split('/')[-1].split('_')[0]
  interpretation_type = file.split('/')[-1].split('_')[1]
  interpretation_number = file.split('/')[-1].split('_')[2]
  song = file.split('/')[-1].split('_')[3].split('.')[0]
  star_table.append([file_name,participant_ID,interpretation_type,interpretation_number, song])

star_table
# Out:
# [['S86_hum_3_StarWars.wav', 'S86', 'hum', '3', 'StarWars'],
#  ['S23_hum_4_StarWars.wav', 'S23', 'hum', '4', 'StarWars'],
#  ['S86_hum_4_StarWars.wav', 'S86', 'hum', '4', 'StarWars'],
#  ['S23_hum_3_StarWars.wav', 'S23', 'hum', '3', 'StarWars'],
#  ['S61_hum_1_StarWars.wav', 'S61', 'hum', '1', 'StarWars'],
#  ['S2_whistle_2_StarWars.wav', 'S2', 'whistle', '2', 'StarWars'],
#  ['S43_hum_2_StarWars.wav', 'S43', 'hum', '2', 'StarWars'],
#  ['S66_whistle_2_StarWars.wav', 'S66', 'whistle', '2', 'StarWars'],
#  ['S88_hum_2_StarWars.wav', 'S88', 'hum', '2', 'StarWars'],
#  ['S91_whistle_2_StarWars.wav', 'S91', 'whistle', '2', 'StarWars'],
#  ['S50_whistle_2_StarWars.wav', 'S50', 'whistle', '2', 'StarWars'],
#  ['S104_hum_3_StarWars.wav', 'S104', 'hum', '3', 'StarWars'],
#  ['S50_hum_2_StarWars.wav', 'S50', 'hum', '2', 'StarWars'],
#  ['S70_hum_4_StarWars.wav', 'S70', 'hum', '4', 'StarWars'],
#  ['S13_hum_4_StarWars.wav', 'S13', 'hum', '4', 'StarWars'],
#  ['S57_whistle_2_StarWars.wav', 'S57', 'whistle', '2', 'StarWars'],
#  ['S70_hum_3_StarWars.wav', 'S70', 'hum', '3', 'StarWars'],
#  ['S13_hum_3_StarWars.wav', 'S13', 'hum', '3', 'StarWars'],
#  ['S73_hum_3_StarWars.wav', 'S73', 'hum', '3', 'StarWars'],
#  ['S10_hum_3_StarWars.wav', 'S10', 'hum', '3', 'StarWars'],
#  ['S73_hum_4_StarWars.wav', 'S73', 'hum', '4', 'StarWars'],
#  ['S10_hum_4_StarWars.wav', 'S10', 'hum', '4', 'StarWars'],
#  ['S109_hum_3_StarWars.wav', 'S109', 'hum', '3', 'StarWars'],
#  ['S96_hum_2_StarWars.wav', 'S96', 'hum', '2', 'StarWars'],
#  ['S104_hum_4_StarWars.wav', 'S104', 'hum', '4', 'StarWars'],
#  ['S1_whistle_2_StarWars.wav', 'S1', 'whistle', '2', 'StarWars'],
#  ['S109_hum_4_StarWars.wav', 'S109', 'hum', '4', 'StarWars'],
#  ['S3_hum_3_StarWars.wav', 'S3', 'hum', '3', 'StarWars'],
#  ['S63_hum_3_StarWars.wav', 'S63', 'hum', '3', 'StarWars'],
#  ['S40_hum_2_StarWars.wav', 'S40', 'hum', '2', 'StarWars'],
#  ['S114_hum_3_StarWars.wav', 'S114', 'hum', '3', 'StarWars'],
#  ['S54_whistle_2_StarWars.wav', 'S54', 'whistle', '2', 'StarWars'],
#  ['S114_hum_4_StarWars.wav', 'S114', 'hum', '4', 'StarWars'],
#  ['S30_hum_4_StarWars.wav', 'S30', 'hum', '4', 'StarWars'],
#  ['S6_whistle_2_StarWars.wav', 'S6', 'whistle', '2', 'StarWars'],
#  ['S53_hum_3_StarWars.wav', 'S53', 'hum', '3', 'StarWars'],
#  ['S107_hum_2_StarWars.wav', 'S107', 'hum', '2', 'StarWars'],
#  ['S30_hum_3_StarWars.wav', 'S30', 'hum', '3', 'StarWars'],
#  ['S68_whistle_2_StarWars.wav', 'S68', 'whistle', '2', 'StarWars'],
#  ['S3_hum_4_StarWars.wav', 'S3', 'hum', '4', 'StarWars'],
#  ['S63_hum_4_StarWars.wav', 'S63', 'hum', '4', 'StarWars'],
#  ['S18_hum_2_StarWars.wav', 'S18', 'hum', '2', 'StarWars'],
#  ['S99_hum_1_StarWars.wav', 'S99', 'hum', '1', 'StarWars'],
#  ['S60_hum_2_StarWars.wav', 'S60', 'hum', '2', 'StarWars'],
#  ['S102_whistle_1_StarWars.wav', 'S102', 'whistle', '1', 'StarWars'],
#  ['S20_hum_3_StarWars.wav', 'S20', 'hum', '3', 'StarWars'],
#  ['S85_hum_4_StarWars.wav', 'S85', 'hum', '4', 'StarWars'],
#  ['S20_hum_4_StarWars.wav', 'S20', 'hum', '4', 'StarWars'],
#  ['S85_hum_3_StarWars.wav', 'S85', 'hum', '3', 'StarWars'],
#  ['S53_hum_4_StarWars.wav', 'S53', 'hum', '4', 'StarWars'],
#  ['S58_hum_3_StarWars.wav', 'S58', 'hum', '3', 'StarWars'],
#  ['S36_hum_3_StarWars.wav', 'S36', 'hum', '3', 'StarWars'],
#  ['S52_whistle_2_StarWars.wav', 'S52', 'whistle', '2', 'StarWars'],
#  ['S58_hum_4_StarWars.wav', 'S58', 'hum', '4', 'StarWars'],
#  ['S93_whistle_2_StarWars.wav', 'S93', 'whistle', '2', 'StarWars'],
#  ['S76_hum_2_StarWars.wav', 'S76', 'hum', '2', 'StarWars'],
#  ['S15_hum_2_StarWars.wav', 'S15', 'hum', '2', 'StarWars'],
#  ['S55_whistle_2_StarWars.wav', 'S55', 'whistle', '2', 'StarWars'],
#  ['S94_whistle_2_StarWars.wav', 'S94', 'whistle', '2', 'StarWars'],
#  ['S26_hum_3_StarWars.wav', 'S26', 'hum', '3', 'StarWars'],
#  ['S26_hum_4_StarWars.wav', 'S26', 'hum', '4', 'StarWars'],
#  ['S37_hum_1_StarWars.wav', 'S37', 'hum', '1', 'StarWars'],
#  ['S66_hum_2_StarWars.wav', 'S66', 'hum', '2', 'StarWars'],
#  ['S16_whistle_2_StarWars.wav', 'S16', 'whistle', '2', 'StarWars'],
#  ['S36_hum_4_StarWars.wav', 'S36', 'hum', '4', 'StarWars'],
#  ['S64_whistle_2_StarWars.wav', 'S64', 'whistle', '2', 'StarWars'],
#  ['S65_hum_4_StarWars.wav', 'S65', 'hum', '4', 'StarWars'],
#  ['S8_hum_3_StarWars.wav', 'S8', 'hum', '3', 'StarWars'],
#  ['S5_hum_4_StarWars.wav', 'S5', 'hum', '4', 'StarWars'],
#  ['S65_hum_3_StarWars.wav', 'S65', 'hum', '3', 'StarWars'],
#  ['S8_hum_4_StarWars.wav', 'S8', 'hum', '4', 'StarWars'],
#  ['S5_hum_3_StarWars.wav', 'S5', 'hum', '3', 'StarWars'],
#  ['S90_hum_2_StarWars.wav', 'S90', 'hum', '2', 'StarWars'],
#  ['S56_hum_2_StarWars.wav', 'S56', 'hum', '2', 'StarWars'],
#  ['S18_whistle_2_StarWars.wav', 'S18', 'whistle', '2', 'StarWars'],
#  ['S111_hum_4_StarWars.wav', 'S111', 'hum', '4', 'StarWars'],
#  ['S48_hum_2_StarWars.wav', 'S48', 'hum', '2', 'StarWars'],
#  ['S29_whistle_2_StarWars.wav', 'S29', 'whistle', '2', 'StarWars'],
#  ['S111_hum_3_StarWars.wav', 'S111', 'hum', '3', 'StarWars'],
#  ['S45_hum_2_StarWars.wav', 'S45', 'hum', '2', 'StarWars'],
#  ['S56_whistle_2_StarWars.wav', 'S56', 'whistle', '2', 'StarWars'],
#  ['S80_hum_2_StarWars.wav', 'S80', 'hum', '2', 'StarWars'],
#  ['S28_hum_4_StarWars.wav', 'S28', 'hum', '4', 'StarWars'],
#  ['S90_whistle_2_StarWars.wav', 'S90', 'whistle', '2', 'StarWars'],
#  ['S24_whistle_2_StarWars.wav', 'S24', 'whistle', '2', 'StarWars'],
#  ['S68_hum_2_StarWars.wav', 'S68', 'hum', '2', 'StarWars'],
#  ['S101_hum_3_StarWars.wav', 'S101', 'hum', '3', 'StarWars'],
#  ['S67_whistle_2_StarWars.wav', 'S67', 'whistle', '2', 'StarWars'],
#  ['S93_hum_2_StarWars.wav', 'S93', 'hum', '2', 'StarWars'],
#  ['S101_hum_4_StarWars.wav', 'S101', 'hum', '4', 'StarWars'],
#  ['S78_hum_2_StarWars.wav', 'S78', 'hum', '2', 'StarWars'],
#  ['S75_hum_2_StarWars.wav', 'S75', 'hum', '2', 'StarWars'],
#  ['S16_hum_2_StarWars.wav', 'S16', 'hum', '2', 'StarWars'],
#  ['S46_hum_4_StarWars.wav', 'S46', 'hum', '4', 'StarWars'],
#  ['S25_hum_4_StarWars.wav', 'S25', 'hum', '4', 'StarWars'],
#  ['S28_hum_3_StarWars.wav', 'S28', 'hum', '3', 'StarWars'],
#  ['S46_hum_3_StarWars.wav', 'S46', 'hum', '3', 'StarWars'],
#  ['S25_hum_3_StarWars.wav', 'S25', 'hum', '3', 'StarWars'],
#  ['S19_hum_4_StarWars.wav', 'S19', 'hum', '4', 'StarWars'],
#  ['S35_hum_3_StarWars.wav', 'S35', 'hum', '3', 'StarWars'],
#  ['S38_hum_4_StarWars.wav', 'S38', 'hum', '4', 'StarWars'],
#  ['S15_whistle_2_StarWars.wav', 'S15', 'whistle', '2', 'StarWars'],
#  ['S35_hum_4_StarWars.wav', 'S35', 'hum', '4', 'StarWars'],
#  ['S38_hum_3_StarWars.wav', 'S38', 'hum', '3', 'StarWars'],
#  ['S43_whistle_2_StarWars.wav', 'S43', 'whistle', '2', 'StarWars'],
#  ['S54_hum_2_StarWars.wav', 'S54', 'hum', '2', 'StarWars'],
#  ['S100_hum_4_StarWars.wav', 'S100', 'hum', '4', 'StarWars'],
#  ['S92_hum_2_StarWars.wav', 'S92', 'hum', '2', 'StarWars'],
#  ['S19_hum_3_StarWars.wav', 'S19', 'hum', '3', 'StarWars'],
#  ['S7_hum_4_StarWars.wav', 'S7', 'hum', '4', 'StarWars'],
#  ['S72_whistle_2_StarWars.wav', 'S72', 'whistle', '2', 'StarWars'],
#  ['S37_hum_2_StarWars.wav', 'S37', 'hum', '2', 'StarWars'],
#  ['S100_hum_3_StarWars.wav', 'S100', 'hum', '3', 'StarWars'],
#  ['S78_whistle_2_StarWars.wav', 'S78', 'whistle', '2', 'StarWars'],
#  ['S103_whistle_2_StarWars.wav', 'S103', 'whistle', '2', 'StarWars'],
#  ['S44_hum_2_StarWars.wav', 'S44', 'hum', '2', 'StarWars'],
#  ['S110_hum_3_StarWars.wav', 'S110', 'hum', '3', 'StarWars'],
#  ['S7_hum_3_StarWars.wav', 'S7', 'hum', '3', 'StarWars'],
#  ['S64_hum_2_StarWars.wav', 'S64', 'hum', '2', 'StarWars'],
#  ['S75_whistle_2_StarWars.wav', 'S75', 'whistle', '2', 'StarWars'],
#  ['S44_whistle_2_StarWars.wav', 'S44', 'whistle', '2', 'StarWars'],
#  ['S103_hum_2_StarWars.wav', 'S103', 'hum', '2', 'StarWars'],
#  ['S49_hum_2_StarWars.wav', 'S49', 'hum', '2', 'StarWars'],
#  ['S110_hum_4_StarWars.wav', 'S110', 'hum', '4', 'StarWars'],
#  ['S67_hum_2_StarWars.wav', 'S67', 'hum', '2', 'StarWars'],
#  ['S47_hum_4_StarWars.wav', 'S47', 'hum', '4', 'StarWars'],
#  ['S47_hum_3_StarWars.wav', 'S47', 'hum', '3', 'StarWars'],
#  ['S77_hum_2_StarWars.wav', 'S77', 'hum', '2', 'StarWars'],
#  ['S82_hum_4_StarWars.wav', 'S82', 'hum', '4', 'StarWars'],
#  ['S82_hum_3_StarWars.wav', 'S82', 'hum', '3', 'StarWars'],
#  ['S49_hum_3_StarWars.wav', 'S49', 'hum', '3', 'StarWars'],
#  ['S32_whistle_2_StarWars.wav', 'S32', 'whistle', '2', 'StarWars'],
#  ['S55_hum_1_StarWars.wav', 'S55', 'hum', '1', 'StarWars'],
#  ['S40_whistle_2_StarWars.wav', 'S40', 'whistle', '2', 'StarWars'],
#  ['S69_hum_4_StarWars.wav', 'S69', 'hum', '4', 'StarWars'],
#  ['S59_hum_3_StarWars.wav', 'S59', 'hum', '3', 'StarWars'],
#  ['S76_whistle_2_Starwars.wav', 'S76', 'whistle', '2', 'Starwars'],
#  ['S92_hum_3_StarWars.wav', 'S92', 'hum', '3', 'StarWars'],
#  ['S59_hum_4_StarWars.wav', 'S59', 'hum', '4', 'StarWars'],
#  ['S107_whistle_2_StarWars.wav', 'S107', 'whistle', '2', 'StarWars'],
#  ['S29_hum_2_StarWars.wav', 'S29', 'hum', '2', 'StarWars'],
#  ['S4_hum_4_StarWars.wav', 'S4', 'hum', '4', 'StarWars'],
#  ['S9_hum_3_StarWars.wav', 'S9', 'hum', '3', 'StarWars'],
#  ['S69_hum_3_StarWars.wav', 'S69', 'hum', '3', 'StarWars'],
#  ['S4_hum_3_StarWars.wav', 'S4', 'hum', '3', 'StarWars'],
#  ['S9_hum_4_StarWars.wav', 'S9', 'hum', '4', 'StarWars'],
#  ['S74_hum_3_StarWars.wav', 'S74', 'hum', '3', 'StarWars'],
#  ['S79_hum_4_StarWars.wav', 'S79', 'hum', '4', 'StarWars'],
#  ['S17_hum_3_StarWars.wav', 'S17', 'hum', '3', 'StarWars'],
#  ['S74_hum_4_StarWars.wav', 'S74', 'hum', '4', 'StarWars'],
#  ['S79_hum_3_StarWars.wav', 'S79', 'hum', '3', 'StarWars'],
#  ['S17_hum_4_StarWars.wav', 'S17', 'hum', '4', 'StarWars'],
#  ['S24_hum_2_StarWars.wav', 'S24', 'hum', '2', 'StarWars'],
#  ['S62_hum_4_StarWars.wav', 'S62', 'hum', '4', 'StarWars'],
#  ['S62_hum_3_StarWars.wav', 'S62', 'hum', '3', 'StarWars'],
#  ['S87_hum_2_StarWars.wav', 'S87', 'hum', '2', 'StarWars'],
#  ['S39_hum_2_StarWars.wav', 'S39', 'hum', '2', 'StarWars'],
#  ['S91_hum_2_StarWars.wav', 'S91', 'hum', '2', 'StarWars'],
#  ['S34_hum_2_StarWars.wav', 'S34', 'hum', '2', 'StarWars'],
#  ['S57_hum_2_StarWars.wav', 'S57', 'hum', '2', 'StarWars'],
#  ['S42_hum_3_StarWars.wav', 'S42', 'hum', '3', 'StarWars'],
#  ['S84_hum_4_StarWars.wav', 'S84', 'hum', '4', 'StarWars'],
#  ['S21_hum_3_StarWars.wav', 'S21', 'hum', '3', 'StarWars'],
#  ['S84_hum_3_StarWars.wav', 'S84', 'hum', '3', 'StarWars'],
#  ['S21_hum_4_StarWars.wav', 'S21', 'hum', '4', 'StarWars'],
#  ['S34_whistle_2_StarWars.wav', 'S34', 'whistle', '2', 'StarWars'],
#  ['S80_whistle_2_StarWars.wav', 'S80', 'whistle', '2', 'StarWars'],
#  ['S32_hum_2_StarWars.wav', 'S32', 'hum', '2', 'StarWars'],
#  ['S87_whistle_2_StarWars.wav', 'S87', 'whistle', '2', 'StarWars'],
#  ['S31_hum_4_StarWars.wav', 'S31', 'hum', '4', 'StarWars'],
#  ['S31_hum_3_StarWars.wav', 'S31', 'hum', '3', 'StarWars'],
#  ['S39_whistle_2_StarWars.wav', 'S39', 'whistle', '2', 'StarWars'],
#  ['S1_hum_2_StarWars.wav', 'S1', 'hum', '2', 'StarWars'],
#  ['S95_hum_1_StarWars.wav', 'S95', 'hum', '1', 'StarWars'],
#  ['S61_hum_2_StarWars.wav', 'S61', 'hum', '2', 'StarWars'],
#  ['S77_whistle_2_StarWars.wav', 'S77', 'whistle', '2', 'StarWars'],
#  ['S97_hum_4_StarWars.wav', 'S97', 'hum', '4', 'StarWars'],
#  ['S51_hum_3_StarWars.wav', 'S51', 'hum', '3', 'StarWars'],
#  ['S97_hum_3_StarWars.wav', 'S97', 'hum', '3', 'StarWars'],
#  ['S108_hum_2_StarWars.wav', 'S108', 'hum', '2', 'StarWars'],
#  ['S105_whistle_2_StarWars.wav', 'S105', 'whistle', '2', 'StarWars'],
#  ['S51_hum_4_StarWars.wav', 'S51', 'hum', '4', 'StarWars'],
#  ['S88_hum_1_StarWars.wav', 'S88', 'hum', '1', 'StarWars'],
#  ['S45_whistle_2_StarWars.wav', 'S45', 'whistle', '2', 'StarWars'],
#  ['S22_hum_4_StarWars.wav', 'S22', 'hum', '4', 'StarWars'],
#  ['S41_hum_3_StarWars.wav', 'S41', 'hum', '3', 'StarWars'],
#  ['S22_hum_3_StarWars.wav', 'S22', 'hum', '3', 'StarWars'],
#  ['S115_hum_2_StarWars.wav', 'S115', 'hum', '2', 'StarWars'],
#  ['S72_hum_2_StarWars.wav', 'S72', 'hum', '2', 'StarWars'],
#  ['S95_whistle_1_StarWars.wav', 'S95', 'whistle', '1', 'StarWars'],
#  ['S102_whistle_2_StarWars.wav', 'S102', 'whistle', '2', 'StarWars'],
#  ['S96_hum_1_StarWars.wav', 'S96', 'hum', '1', 'StarWars'],
#  ['S2_hum_2_StarWars.wav', 'S2', 'hum', '2', 'StarWars'],
#  ['S41_hum_4_StarWars.wav', 'S41', 'hum', '4', 'StarWars'],
#  ['S52_hum_2_StarWars.wav', 'S52', 'hum', '2', 'StarWars'],
#  ['S99_hum_2_StarWars.wav', 'S99', 'hum', '2', 'StarWars'],
#  ['S60_hum_1_StarWars.wav', 'S60', 'hum', '1', 'StarWars'],
#  ['S94_hum_2_StarWars.wav', 'S94', 'hum', '2', 'StarWars'],
#  ['S89_hum_2_StarWars.wav', 'S89', 'hum', '2', 'StarWars'],
#  ['S42_hum_2_StarWars.wav', 'S42', 'hum', '2', 'StarWars'],
#  ['S12_hum_4_StarWars.wav', 'S12', 'hum', '4', 'StarWars'],
#  ['S71_hum_4_StarWars.wav', 'S71', 'hum', '4', 'StarWars'],
#  ['S108_whistle_2_StarWars.wav', 'S108', 'whistle', '2', 'StarWars'],
#  ['S12_hum_3_StarWars.wav', 'S12', 'hum', '3', 'StarWars'],
#  ['S71_hum_3_StarWars.wav', 'S71', 'hum', '3', 'StarWars'],
#  ['S6_whistle_1_StarWars.wav', 'S6', 'whistle', '1', 'StarWars'],
#  ['S48_whistle_2_StarWars.wav', 'S48', 'whistle', '2', 'StarWars'],
#  ['S89_whistle_2_StarWars.wav', 'S89', 'whistle', '2', 'StarWars']]

# %%
starwars_df = pd.DataFrame(star_table,columns=['file_id','participant','interpretation','number','song']).set_index('file_id') 
starwars_df
# Out:
#                            participant interpretation number      song
# file_id
# S86_hum_3_StarWars.wav             S86            hum      3  StarWars
# S23_hum_4_StarWars.wav             S23            hum      4  StarWars
# S86_hum_4_StarWars.wav             S86            hum      4  StarWars
# S23_hum_3_StarWars.wav             S23            hum      3  StarWars
# S61_hum_1_StarWars.wav             S61            hum      1  StarWars
# ...                                ...            ...    ...       ...
# S12_hum_3_StarWars.wav             S12            hum      3  StarWars
# S71_hum_3_StarWars.wav             S71            hum      3  StarWars
# S6_whistle_1_StarWars.wav           S6        whistle      1  StarWars
# S48_whistle_2_StarWars.wav         S48        whistle      2  StarWars
# S89_whistle_2_StarWars.wav         S89        whistle      2  StarWars
#
# [208 rows x 4 columns]

# %%
MLEndHWdf = pd.concat([potter_df,starwars_df])
MLEndHWdf
# Out:
#                            participant interpretation number      song
# file_id
# S77_whistle_2_Potter.wav           S77        whistle      2    Potter
# S36_hum_1_Potter.wav               S36            hum      2    Potter
# S54_hum_2_Potter.wav               S54            hum      2    Potter
# S35_hum_1_[Potter].wav             S35            hum      2    Potter
# S31_hum_2_Potter.wav               S31            hum      2    Potter
# ...                                ...            ...    ...       ...
# S12_hum_3_StarWars.wav             S12            hum      3  StarWars
# S71_hum_3_StarWars.wav             S71            hum      3  StarWars
# S6_whistle_1_StarWars.wav           S6        whistle      1  StarWars
# S48_whistle_2_StarWars.wav         S48        whistle      2  StarWars
# S89_whistle_2_StarWars.wav         S89        whistle      2  StarWars
#
# [414 rows x 4 columns]

# %%
files = files_potter + files_starwars

# %%
n=0
fs = None # Sampling frequency. If None, fs would be 22050
x, fs = librosa.load(files[n],sr=fs)
t = np.arange(len(x))/fs
plt.plot(t,x)
plt.xlabel('time (sec)')
plt.ylabel('amplitude')
plt.show()
display(ipd.Audio(files[n]))

n=0
x, fs = librosa.load(files[n],sr=fs)
print('This audio signal has', len(x), 'samples')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # 8 Results
#
# **Carry out your experiments here, explain your results.**

# %%
def getPitch(x,fs,winLen=0.02):
  #winLen = 0.02 
  p = winLen*fs
  frame_length = int(2**int(p-1).bit_length())
  hop_length = frame_length//2
  f0, voiced_flag, voiced_probs = librosa.pyin(y=x, fmin=80, fmax=450, sr=fs,
                                                 frame_length=frame_length,hop_length=hop_length)
  return f0,voiced_flag

# %%
def getXy(files,labels_file, scale_audio=False, onlySingleDigit=False):
  X,y =[],[]
  for file in tqdm(files):
    fileID = file.split('/')[-1]
    file_name = file.split('/')[-1]
    #print(file_name)
    #print(labels_file.loc[fileID]['interpretation'])
    #print(labels_file.loc[fileID]['interpretation']=='hum')
    #yi = list(labels_file.loc[fileID]['interpretation'])[0]=='hum'
    yi = labels_file.loc[fileID]['song']=='Potter'

    fs = None # if None, fs would be 22050
    x, fs = librosa.load(file,sr=fs)
    if scale_audio: x = x/np.max(np.abs(x))
    f0, voiced_flag = getPitch(x,fs,winLen=0.02)
      
    power = np.sum(x**2)/len(x)
    pitch_mean = np.nanmean(f0) if np.mean(np.isnan(f0))<1 else 0
    pitch_std  = np.nanstd(f0) if np.mean(np.isnan(f0))<1 else 0
    voiced_fr = np.mean(voiced_flag)

    xi = [power,pitch_mean,pitch_std,voiced_fr]
    X.append(xi)
    y.append(yi)

  return np.array(X),np.array(y)

# %%
X,y = getXy(files, labels_file=MLEndHWdf, scale_audio=True, onlySingleDigit=True)
# Out:
# 100%|██████████| 414/414 [19:41<00:00,  2.85s/it]

# %%
print('The shape of X is', X.shape) 
print('The shape of y is', y.shape)
print('The labels vector is', y)
# Out:
# The shape of X is (414, 4)
# The shape of y is (414,)
# The labels vector is [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False]

# %%
print(' The number of hum recordings is ', np.count_nonzero(y))
print(' The number of whistle recordings is ', y.size - np.count_nonzero(y))
# Out:
#  The number of hum recordings is  206
#  The number of whistle recordings is  208

# %%
from sklearn import svm
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(X,y,test_size=0.3)
X_train.shape, X_val.shape, y_train.shape, y_val.shape
# Out:
# ((289, 4), (125, 4), (289,), (125,))

# %%
model  = svm.SVC(C=1)
model.fit (X_train,y_train)

yt_p = model.predict(X_train)
yv_p = model.predict(X_val)

print('Training Accuracy', np.mean(yt_p==y_train))
print('Validation  Accuracy', np.mean(yv_p==y_val))
print('The support vectors are', model.support_vectors_.shape)
# Out:
# Training Accuracy 0.5536332179930796
# Validation  Accuracy 0.504
# The support vectors are (277, 4)

# %% [markdown]
# Looking at the results produced it can be concluded that the label of the audio file can be identified using this model from the initial raw audio files.The feature extraction (Pitch) that was used allowed the model to determine whether or not the audio file was labelled Potter by providing a True or False response. The accuracy of the training set produced a value of 0.55 and the accuracy of the validation set produced a value of 0.50. This would indicate that the model fits well. However, the accuracy for both the training and validation sets were quite low, which could mean that the model might not have been able to identify some of the audio files correctly based on their pitch.

# %% [markdown]
# # 9 Conclusions
#
# In conclusion, this mini-project showed that using specific feature extractions such as pitch, machine learning problems that require classifications can be distinguished using models such as SVM.
