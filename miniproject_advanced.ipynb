# %% [markdown]
# # ECS7020P mini-project submission (Advanced Solution)
#
# The mini-project consists of two components:
#
#
# 1.   **Basic solution** [6 marks]: Using the MLEnd Hums and Whistles dataset, build a machine learning pipeline that takes as an input a Potter or a StarWars audio segment and predicts its song label (either Harry or StarWars).
# 2.   **Advanced solution** [10 marks]: There are two options. (i) Formulate a machine learning problem that can be attempted using the MLEnd Hums and Whistles dataset and build a solution model. (ii) Create a product that uses the functionality provided by a model trained on the MLEnd Hums and Whistles dataset (e.g. a simple App that predicts the label Harry or StarWars when you hum to it).
#
# The submission will consist of two Jupyter notebooks, one for the basic solution and another one for advanced solution. Please **name each notebook**:
#
# * ECS7020P_miniproject_basic.ipynb
# * ECS7020P_miniproject_advanced.ipynb
#
# then **zipped and submitted toghether**.
#
# Each uploaded notebook should consist of:
#
# *   **Text cells**, describing concisely each step and results.
# *   **Code cells**, implementing each step.
# *   **Output cells**, i.e. the output from each code cell.
#
# and **should have the structure** indicated below. Notebooks will not be run, please make sure that the output cells are saved.
#
# How will we evaluate your submission?
#
# *   Conciseness in your writing (10%).
# *   Correctness in your methodology (30%).
# *   Correctness in your analysis and conclusions (30%).
# *   Completeness (10%).
# *   Originality (10%).
# *   Efforts to try something new (10%).
#
# Suggestion: Why don't you use **GitHub** to manage your project? GitHub can be used as a presentation card that showcases what you have done and gives evidence of your data science skills, knowledge and experience.
#
# Each notebook should be structured into the following 9 sections:

# %% [markdown]
# # 1 Author
#
# **Student Name**:  Faysal Ali
# **Student ID**:  180135787

# %% [markdown]
# # 2 Problem formulation
#
# **Describe the machine learning problem that you want to solve and explain what's interesting about it.**
#
# In this Mini-project, the MLEnds Hums and Whistles dataset was used to predict the label of a song from the an audio file that contained either a hum or whistle. The two sets of files used for the basic solution of this project contained a small section of audio from the theme songs of The Great Showman and Mamma Mia. The interesting part of this machine learning problem was the use of certain features in the audio file that allowed the model to easily distinguish what theme song the audio file belonged to.

# %% [markdown]
# # 3 Machine Learning pipeline
#
# **Describe your ML pipeline. Clearly identify its input and output, any intermediate stages (for instance, transformation -> models), and intermediate data moving from one stage to the next. Note that your pipeline does not need to include all the stages.**
#
# The Machine learning pipeline that was used for this project consisted of using the inputs (Hum and Whistle audio files for The Great Showman and Mamma Mia) and classifying the song label as Showman or Mamma as the output. In order for the model to function without any errors or have data missing, the raw data was cleaned and the file names were corrected. The dataset that was used was part 1 folders for both Showman and Mamma. The overall dataset that was used for this model included 428 audio files. Each of the files followed a certain structure when it came to file_id and Interpretation number, which allowed a dataframe to be created using the audio files. The dataframe created was used to extract the information that was required by the model.

# %% [markdown]
# # 4 Transformation stage
#
# **Describe any transformations, such as feature extraction. Identify input and output.**
#
# The feature extraction that was used for this machine learning problem was Pitch. The pitch was used to distinguish between the different audio files that correspond to specific song labels.Since the audio file contained a large number of dimensions, using the pitch as the feature extraction allowed it to be reduced to 5 dimension:
# 1.   Power.
# 2.   Pitch mean.
# 3.   Pitch standard deviation.
# 4.   Fraction of voiced region.
#
# These 5 features were then used as predictors.

# %% [markdown]
# # 5 Modelling
#
# **Describe the ML models that you will implement.**
#
# A support vector machine (SVM) model was used to predict and distinguish whether the audio file was Showman or Mamma. The dataset was then split into a training set and a validation set, with the accuracy of the training and validation sets compared.

# %% [markdown]
# # 6 Methodology
#
# **Describe how you will train and validate your models, how model performance is assesssed (i.e. accuracy, confusion matrix, etc)**
#
# In order to train the SVM model a classifier is created and used to class the data. The SVM model takes two arrays as an input: an array X of the shape holding the training set and array y holding the class labels. The classes are then predicted using the test set, with the training set and validation set accuracies then compared.

# %% [markdown]
# # 7 Dataset
#
# **Describe the dataset that you will use to create your models and validate them. If you need to preprocess it, do it here. Include visualisations too. You can visualise raw data samples or extracted features.**

# %%
from google.colab import drive

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import os, sys, re, pickle, glob
import urllib.request
import zipfile

import IPython.display as ipd
from tqdm import tqdm
import librosa

drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/Data/Showman_1'
os.listdir(path)
# Out:
# ['S99_hum_1_[Showman].wav',
#  'S36_hum_3_Showman.wav',
#  'S75_hum_1_Showman.wav',
#  'S3_hum_4_Showman.wav',
#  'S23_hum_4_Showman.wav',
#  'S91_hum_1_Showman.wav',
#  'S106_hum_3_Showman.WAV',
#  'S44_hum_1_Showman.wav',
#  'S8_hum_1_[Showman].wav',
#  'S77_whistle_2_Showman.wav',
#  'S26_hum_4_Showman.wav',
#  'S94_hum_1_Showman.wav',
#  'S45_whistle_2_Showman.wav',
#  'S71_hum_4_Showman.wav',
#  'S59_hum_4_Showman.wav',
#  'S17_hum_4_Showman.wav',
#  'S6_whisle_1_Showman.wav',
#  'S2_whistle_2_Showman.wav',
#  'S40_hum_1_showman.wav',
#  'S74_hum_4_Showman.wav',
#  'S85_hum_3_Showman.wav',
#  'S16_hum_1_Showman.wav',
#  'S12_hum_4_Showman.wav',
#  'S82_hum_1_[Showman].wav',
#  'S2_hum_1_Showman.wav',
#  'S82_hum_2_[Showman].wav',
#  'S58_hum_4_Showman.wav',
#  'S103_whistle_2_Showman.wav',
#  'S65_hum_3_Showman.wav',
#  'S29_whistle_2_Showman.wav',
#  'S68_hum_1_Showman.wav',
#  'S22_hum_4_Showman.wav',
#  'S90_hum_1_Showman.wav',
#  'S8_hum_2_[Showman].wav',
#  'S89_whistle_2_Showman.wav',
#  'S99_hum_2_[Showman].wav',
#  'S13_hum_4_Showman.wav',
#  'S75_whistle_2_Showman.wav',
#  'S41_hum_4_Showman.wav',
#  'S7_hum_4_Showman.wav',
#  'S45_hum_1_Showman.wav',
#  'S69_hum_4_Showman.wav',
#  'S51_hum_3_Showman.wav',
#  'S70_hum_4_Showman.wav',
#  'S28_hum_3_Showman.wav',
#  'S60_hum_1_[Showman].wav',
#  'S47_hum_4_showman.wav',
#  'S93_hum_1_Showman.wav',
#  'S104_Hum_3_Showman.wav',
#  'S79_hum_1_[Showman].wav',
#  'S21_hum_4_Showman.wav',
#  'S43_hum_1_Showman.wav',
#  'S84_hum_3_Showman.wav',
#  'S89_hum_1_Showman.wav',
#  'S115_hum_1_Showman.wav',
#  'S87_whistle_2_Showman.wav',
#  'S91_whistle_2_Showman.wav',
#  'S77_hum_1_Showman.wav',
#  'S111_hum_4_Showman.wav',
#  'S39_hum_1_Showman.wav',
#  'S55_thisisme_hum_2.wav',
#  'S97_hum_4_Showman.wav',
#  'S15_whistle_2_Showman.wav',
#  'S88_hum_1_[Showman].wav',
#  'S92_Hum_4_Showman.wav',
#  'S101_hum_3_Showman.wav',
#  'S24_hum_4_ShowMan.wav',
#  'S61_hum_1_[Showman].wav',
#  'S37_hum_2_[Showman].wav',
#  'S73_hum_4_Showman.wav',
#  'S35_hum_2_[Showman].wav',
#  'S72_hum_1_Showman.wav',
#  'S57_whistle_2_Showman.wav',
#  'S31_hum_3_Showman.wav',
#  'S39_whistle_2_Showman.wav',
#  'S10_hum_4_Showman.wav',
#  'S63_hum_1_[Showman].wav',
#  'S55_thisisme_hum_1.wav',
#  'S4_hum_4_Showman.wav',
#  'S88_hum_2_[Showman].wav',
#  'S46_hum_4_Showman.wav',
#  'S20_hum_4_Showman.wav',
#  'S108_hum_1_Showman.wav',
#  'S93_whistle_2_Showman.wav',
#  'S9_hum_3_Showman.wav',
#  'S38_hum_4_Showman.wav',
#  'S6_whisle_2_Showman.wav',
#  'S19_hum_3_Showman.wav',
#  'S114_hum_4_showman.wav',
#  'S53_hum_3_Showman.wav',
#  'S67_whistle_2_Showman.wav',
#  'S63_hum_2_[Showman].wav',
#  'S14_hum_4_Showman.wav',
#  'S110_hum_4_Showman.wav',
#  'S76_hum_1_Showman.wav',
#  'S5_hum_1_thisisme.wav',
#  'S35_hum_1_[Showman].wav',
#  'S42_Hum4_Showman.wav',
#  'S61_hum_2_[Showman].wav',
#  'S107_whistle_2_Showman.wav',
#  'S30_hum_3_Showman.wav',
#  'S60_hum_2_[Showman].wav',
#  'S62_hum_3_Showman.wav',
#  'S43_whistle_2_Showman.wav',
#  'S1_hum_1_Showman.wav',
#  'S100_hum_3_Showman.wav',
#  'S79_hum_2_[Showman].wav',
#  'S25_hum_4_Showman.wav',
#  'S18_Whistle_2_Showman.wav',
#  'S108_whistle_2_Showman.wav',
#  'S25_hum_3_Showman.wav',
#  'S49_hum_4_[ Showman ].wav',
#  'S100_hum_4_Showman.wav',
#  'S66_hum_1_Showman.wav',
#  'S86_hum_3_Showman.wav',
#  'S37_hum_1_[Showman].wav',
#  'S15_hum_1_Showman.wav',
#  'S34_whistle_2_Showman.wav',
#  'S95_Hum 1 Showman.wav',
#  'S52_hum_1_Showman.wav',
#  'S109_hum_1_[Showman].wav',
#  'S62_hum_4_Showman.wav',
#  'S76_whistle_2_Showman.wav',
#  'S86_hum_4_Showman.wav',
#  'S34_hum_1_Showman.wav',
#  'S94_whistle_2_Showman.wav',
#  'S30_hum_4_Showman.wav',
#  'S105_hum_2_this is me.wav',
#  'S46_hum_3_Showman.wav',
#  'S68_whistle_2_Showman.wav',
#  'S20_hum_3_Showman.wav',
#  'S9_hum_4_Showman.wav',
#  'S5_hum_3_thisisme.wav',
#  'S110_hum_3_Showman.wav',
#  'S42_Hum3_Showman.wav',
#  'S101_hum_4_Showman.wav',
#  'S53_hum_4_Showman.wav',
#  'S52_whistle_2_Showman.wav',
#  'S1_whistle_2_Showman.wav',
#  'S14_hum_3_Showman.wav',
#  'S57_hum_1_Showman.wav',
#  'S44_whistle_2_Showman.wav',
#  'S87_hum_1_Showman.wav',
#  'S10_hum_3_Showman.wav',
#  'S4_hum_3_Showman.wav',
#  'S92_Hum_3_Showman.wav',
#  'S80_whistle_2_Showman.wav',
#  'S24_hum_3_ShowMan.wav',
#  'S29_hum_1_Showman.wav',
#  'S95_Whistle 2 Showman.wav',
#  'S67_hum_1_Showman.wav',
#  'S47_hum_3_showman.wav',
#  'S21_hum_3_Showman.wav',
#  'S104_Hum_4_Showman.wav',
#  'S38_hum_3_Showman.wav',
#  'S19_hum_4_Showman.wav',
#  'S31_hum_4_Showman.wav',
#  'S114_hum_3_showman.wav',
#  'S69_hum_3_Showman.wav',
#  'S73_hum_3_Showman.wav',
#  'S102_whistle_2_Showman.wav',
#  'S18_Hum_1_Showman.wav',
#  'S56_hum_1_Showman.wav',
#  'S111_hum_3_Showman.wav',
#  'S97_hum_3_Showman.wav',
#  'S28_hum_4_Showman.wav',
#  'S109_hum_2_[Showman].wav',
#  'S84_hum_4_Showman.wav',
#  'S56_whistle_2_Showman.wav',
#  'S80_hum_1_Showman.wav',
#  'S40_whistle_2_showman.wav',
#  'S13_hum_3_Showman.wav',
#  'S7_hum_3_Showman.wav',
#  'S41_hum_3_Showman.wav',
#  'S105_hum_1_this is me.wav',
#  'S64_hum_1_Showman.wav',
#  'S70_hum_3_Showman.wav',
#  'S58_hum_3_Showman.wav',
#  'S49_hum_2_[ Showman ].wav',
#  'S72_whistle_2_Showman.wav',
#  'S103_hum_1_Showman.wav',
#  'S65_hum_4_Showman.wav',
#  'S22_hum_3_Showman.wav',
#  'S64_whistle_2_Showman.wav',
#  'S78_hum_1_Showman.wav',
#  'S16_whistle_2_Showman.wav',
#  'S78_whistle_2_Showman.wav',
#  'S54_whistle_2_Showman.wav',
#  'S107_hum_1_Showman.wav',
#  'S26_hum_3_Showman.wav',
#  'S90_whistle_2_Showman.wav',
#  'S48_Whistle_2_Showman.wav',
#  'S51_hum_4_Showman.wav',
#  'S102_hum_1_Showman.wav',
#  'S48_Hum_1_Showman.wav',
#  'S3_hum_3_Showman.wav',
#  'S106_hum_4_Showman.WAV',
#  'S23_hum_3_Showman.wav',
#  'S32_whistle_2_Showman.wav',
#  'S85_hum_4_Showman.wav',
#  'S74_hum_3_Showman.wav',
#  'S12_hum_3_Showman.wav',
#  'S54_hum_1_Showman.wav',
#  'S59_hum_3_Showman.wav',
#  'S17_hum_3_Showman.wav',
#  'S36_hum_4_Showman.wav',
#  'S66_whistle_2_Showman.wav',
#  'S32_hum_1_Showman.wav',
#  'S71_hum_3_Showman.wav']

# %%
sample_path = '/content/drive/MyDrive/Data/Showman_1/*.wav'
files_showman = glob.glob(sample_path)
len(files_showman)
for _ in range(5):
  n1 = np.random.randint(210)
  display(ipd.Audio(files_showman[n1]))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
show_table = [] 

for file in files_showman:
  file_name = file.split('/')[-1]
  participant_ID = file.split('/')[-1].split('_')[0]
  interpretation_type = file.split('/')[-1].split('_')[1]
  #interpretation_number = file.split('/')[-1].split('_')[2]
  #song = file.split('/')[-1].split('_')[3].split('.')[0]
  show_table.append([file_name,participant_ID,interpretation_type,interpretation_number, song])

show_table
# Out:
# [['S99_hum_1_[Showman].wav', 'S99', 'hum', 'Showman.wav', '[Showman]'],
#  ['S36_hum_3_Showman.wav', 'S36', 'hum', 'Showman.wav', '[Showman]'],
#  ['S75_hum_1_Showman.wav', 'S75', 'hum', 'Showman.wav', '[Showman]'],
#  ['S3_hum_4_Showman.wav', 'S3', 'hum', 'Showman.wav', '[Showman]'],
#  ['S23_hum_4_Showman.wav', 'S23', 'hum', 'Showman.wav', '[Showman]'],
#  ['S91_hum_1_Showman.wav', 'S91', 'hum', 'Showman.wav', '[Showman]'],
#  ['S44_hum_1_Showman.wav', 'S44', 'hum', 'Showman.wav', '[Showman]'],
#  ['S8_hum_1_[Showman].wav', 'S8', 'hum', 'Showman.wav', '[Showman]'],
#  ['S77_whistle_2_Showman.wav', 'S77', 'whistle', 'Showman.wav', '[Showman]'],
#  ['S26_hum_4_Showman.wav', 'S26', 'hum', 'Showman.wav', '[Showman]'],
#  ['S94_hum_1_Showman.wav', 'S94', 'hum', 'Showman.wav', '[Showman]'],
#  ['S45_whistle_2_Showman.wav', 'S45', 'whistle', 'Showman.wav', '[Showman]'],
#  ['S71_hum_4_Showman.wav', 'S71', 'hum', 'Showman.wav', '[Showman]'],
#  ['S59_hum_4_Showman.wav', 'S59', 'hum', 'Showman.wav', '[Showman]'],
#  ['S17_hum_4_Showman.wav', 'S17', 'hum', 'Showman.wav', '[Showman]'],
#  ['S6_whisle_1_Showman.wav', 'S6', 'whisle', 'Showman.wav', '[Showman]'],
#  ['S2_whistle_2_Showman.wav', 'S2', 'whistle', 'Showman.wav', '[Showman]'],
#  ['S40_hum_1_showman.wav', 'S40', 'hum', 'Showman.wav', '[Showman]'],
#  ['S74_hum_4_Showman.wav', 'S74', 'hum', 'Showman.wav', '[Showman]'],
#  ['S85_hum_3_Showman.wav', 'S85', 'hum', 'Showman.wav', '[Showman]'],
#  ['S16_hum_1_Showman.wav', 'S16', 'hum', 'Showman.wav', '[Showman]'],
#  ['S12_hum_4_Showman.wav', 'S12', 'hum', 'Showman.wav', '[Showman]'],
#  ['S82_hum_1_[Showman].wav', 'S82', 'hum', 'Showman.wav', '[Showman]'],
#  ['S2_hum_1_Showman.wav', 'S2', 'hum', 'Showman.wav', '[Showman]'],
#  ['S82_hum_2_[Showman].wav', 'S82', 'hum', 'Showman.wav', '[Showman]'],
#  ['S58_hum_4_Showman.wav', 'S58', 'hum', 'Showman.wav', '[Showman]'],
#  ['S103_whistle_2_Showman.wav', 'S103', 'whistle', 'Showman.wav', '[Showman]'],
#  ['S65_hum_3_Showman.wav', 'S65', 'hum', 'Showman.wav', '[Showman]'],
#  ['S29_whistle_2_Showman.wav', 'S29', 'whistle', 'Showman.wav', '[Showman]'],
#  ['S68_hum_1_Showman.wav', 'S68', 'hum', 'Showman.wav', '[Showman]'],
#  ['S22_hum_4_Showman.wav', 'S22', 'hum', 'Showman.wav', '[Showman]'],
#  ['S90_hum_1_Showman.wav', 'S90', 'hum', 'Showman.wav', '[Showman]'],
#  ['S8_hum_2_[Showman].wav', 'S8', 'hum', 'Showman.wav', '[Showman]'],
#  ['S89_whistle_2_Showman.wav', 'S89', 'whistle', 'Showman.wav', '[Showman]'],
#  ['S99_hum_2_[Showman].wav', 'S99', 'hum', 'Showman.wav', '[Showman]'],
#  ['S13_hum_4_Showman.wav', 'S13', 'hum', 'Showman.wav', '[Showman]'],
#  ['S75_whistle_2_Showman.wav', 'S75', 'whistle', 'Showman.wav', '[Showman]'],
#  ['S41_hum_4_Showman.wav', 'S41', 'hum', 'Showman.wav', '[Showman]'],
#  ['S7_hum_4_Showman.wav', 'S7', 'hum', 'Showman.wav', '[Showman]'],
#  ['S45_hum_1_Showman.wav', 'S45', 'hum', 'Showman.wav', '[Showman]'],
#  ['S69_hum_4_Showman.wav', 'S69', 'hum', 'Showman.wav', '[Showman]'],
#  ['S51_hum_3_Showman.wav', 'S51', 'hum', 'Showman.wav', '[Showman]'],
#  ['S70_hum_4_Showman.wav', 'S70', 'hum', 'Showman.wav', '[Showman]'],
#  ['S28_hum_3_Showman.wav', 'S28', 'hum', 'Showman.wav', '[Showman]'],
#  ['S60_hum_1_[Showman].wav', 'S60', 'hum', 'Showman.wav', '[Showman]'],
#  ['S47_hum_4_showman.wav', 'S47', 'hum', 'Showman.wav', '[Showman]'],
#  ['S93_hum_1_Showman.wav', 'S93', 'hum', 'Showman.wav', '[Showman]'],
#  ['S104_Hum_3_Showman.wav', 'S104', 'Hum', 'Showman.wav', '[Showman]'],
#  ['S79_hum_1_[Showman].wav', 'S79', 'hum', 'Showman.wav', '[Showman]'],
#  ['S21_hum_4_Showman.wav', 'S21', 'hum', 'Showman.wav', '[Showman]'],
#  ['S43_hum_1_Showman.wav', 'S43', 'hum', 'Showman.wav', '[Showman]'],
#  ['S84_hum_3_Showman.wav', 'S84', 'hum', 'Showman.wav', '[Showman]'],
#  ['S89_hum_1_Showman.wav', 'S89', 'hum', 'Showman.wav', '[Showman]'],
#  ['S115_hum_1_Showman.wav', 'S115', 'hum', 'Showman.wav', '[Showman]'],
#  ['S87_whistle_2_Showman.wav', 'S87', 'whistle', 'Showman.wav', '[Showman]'],
#  ['S91_whistle_2_Showman.wav', 'S91', 'whistle', 'Showman.wav', '[Showman]'],
#  ['S77_hum_1_Showman.wav', 'S77', 'hum', 'Showman.wav', '[Showman]'],
#  ['S111_hum_4_Showman.wav', 'S111', 'hum', 'Showman.wav', '[Showman]'],
#  ['S39_hum_1_Showman.wav', 'S39', 'hum', 'Showman.wav', '[Showman]'],
#  ['S55_thisisme_hum_2.wav', 'S55', 'thisisme', 'Showman.wav', '[Showman]'],
#  ['S97_hum_4_Showman.wav', 'S97', 'hum', 'Showman.wav', '[Showman]'],
#  ['S15_whistle_2_Showman.wav', 'S15', 'whistle', 'Showman.wav', '[Showman]'],
#  ['S88_hum_1_[Showman].wav', 'S88', 'hum', 'Showman.wav', '[Showman]'],
#  ['S92_Hum_4_Showman.wav', 'S92', 'Hum', 'Showman.wav', '[Showman]'],
#  ['S101_hum_3_Showman.wav', 'S101', 'hum', 'Showman.wav', '[Showman]'],
#  ['S24_hum_4_ShowMan.wav', 'S24', 'hum', 'Showman.wav', '[Showman]'],
#  ['S61_hum_1_[Showman].wav', 'S61', 'hum', 'Showman.wav', '[Showman]'],
#  ['S37_hum_2_[Showman].wav', 'S37', 'hum', 'Showman.wav', '[Showman]'],
#  ['S73_hum_4_Showman.wav', 'S73', 'hum', 'Showman.wav', '[Showman]'],
#  ['S35_hum_2_[Showman].wav', 'S35', 'hum', 'Showman.wav', '[Showman]'],
#  ['S72_hum_1_Showman.wav', 'S72', 'hum', 'Showman.wav', '[Showman]'],
#  ['S57_whistle_2_Showman.wav', 'S57', 'whistle', 'Showman.wav', '[Showman]'],
#  ['S31_hum_3_Showman.wav', 'S31', 'hum', 'Showman.wav', '[Showman]'],
#  ['S39_whistle_2_Showman.wav', 'S39', 'whistle', 'Showman.wav', '[Showman]'],
#  ['S10_hum_4_Showman.wav', 'S10', 'hum', 'Showman.wav', '[Showman]'],
#  ['S63_hum_1_[Showman].wav', 'S63', 'hum', 'Showman.wav', '[Showman]'],
#  ['S55_thisisme_hum_1.wav', 'S55', 'thisisme', 'Showman.wav', '[Showman]'],
#  ['S4_hum_4_Showman.wav', 'S4', 'hum', 'Showman.wav', '[Showman]'],
#  ['S88_hum_2_[Showman].wav', 'S88', 'hum', 'Showman.wav', '[Showman]'],
#  ['S46_hum_4_Showman.wav', 'S46', 'hum', 'Showman.wav', '[Showman]'],
#  ['S20_hum_4_Showman.wav', 'S20', 'hum', 'Showman.wav', '[Showman]'],
#  ['S108_hum_1_Showman.wav', 'S108', 'hum', 'Showman.wav', '[Showman]'],
#  ['S93_whistle_2_Showman.wav', 'S93', 'whistle', 'Showman.wav', '[Showman]'],
#  ['S9_hum_3_Showman.wav', 'S9', 'hum', 'Showman.wav', '[Showman]'],
#  ['S38_hum_4_Showman.wav', 'S38', 'hum', 'Showman.wav', '[Showman]'],
#  ['S6_whisle_2_Showman.wav', 'S6', 'whisle', 'Showman.wav', '[Showman]'],
#  ['S19_hum_3_Showman.wav', 'S19', 'hum', 'Showman.wav', '[Showman]'],
#  ['S114_hum_4_showman.wav', 'S114', 'hum', 'Showman.wav', '[Showman]'],
#  ['S53_hum_3_Showman.wav', 'S53', 'hum', 'Showman.wav', '[Showman]'],
#  ['S67_whistle_2_Showman.wav', 'S67', 'whistle', 'Showman.wav', '[Showman]'],
#  ['S63_hum_2_[Showman].wav', 'S63', 'hum', 'Showman.wav', '[Showman]'],
#  ['S14_hum_4_Showman.wav', 'S14', 'hum', 'Showman.wav', '[Showman]'],
#  ['S110_hum_4_Showman.wav', 'S110', 'hum', 'Showman.wav', '[Showman]'],
#  ['S76_hum_1_Showman.wav', 'S76', 'hum', 'Showman.wav', '[Showman]'],
#  ['S5_hum_1_thisisme.wav', 'S5', 'hum', 'Showman.wav', '[Showman]'],
#  ['S35_hum_1_[Showman].wav', 'S35', 'hum', 'Showman.wav', '[Showman]'],
#  ['S42_Hum4_Showman.wav', 'S42', 'Hum4', 'Showman.wav', '[Showman]'],
#  ['S61_hum_2_[Showman].wav', 'S61', 'hum', 'Showman.wav', '[Showman]'],
#  ['S107_whistle_2_Showman.wav', 'S107', 'whistle', 'Showman.wav', '[Showman]'],
#  ['S30_hum_3_Showman.wav', 'S30', 'hum', 'Showman.wav', '[Showman]'],
#  ['S60_hum_2_[Showman].wav', 'S60', 'hum', 'Showman.wav', '[Showman]'],
#  ['S62_hum_3_Showman.wav', 'S62', 'hum', 'Showman.wav', '[Showman]'],
#  ['S43_whistle_2_Showman.wav', 'S43', 'whistle', 'Showman.wav', '[Showman]'],
#  ['S1_hum_1_Showman.wav', 'S1', 'hum', 'Showman.wav', '[Showman]'],
#  ['S100_hum_3_Showman.wav', 'S100', 'hum', 'Showman.wav', '[Showman]'],
#  ['S79_hum_2_[Showman].wav', 'S79', 'hum', 'Showman.wav', '[Showman]'],
#  ['S25_hum_4_Showman.wav', 'S25', 'hum', 'Showman.wav', '[Showman]'],
#  ['S18_Whistle_2_Showman.wav', 'S18', 'Whistle', 'Showman.wav', '[Showman]'],
#  ['S108_whistle_2_Showman.wav', 'S108', 'whistle', 'Showman.wav', '[Showman]'],
#  ['S25_hum_3_Showman.wav', 'S25', 'hum', 'Showman.wav', '[Showman]'],
#  ['S49_hum_4_[ Showman ].wav', 'S49', 'hum', 'Showman.wav', '[Showman]'],
#  ['S100_hum_4_Showman.wav', 'S100', 'hum', 'Showman.wav', '[Showman]'],
#  ['S66_hum_1_Showman.wav', 'S66', 'hum', 'Showman.wav', '[Showman]'],
#  ['S86_hum_3_Showman.wav', 'S86', 'hum', 'Showman.wav', '[Showman]'],
#  ['S37_hum_1_[Showman].wav', 'S37', 'hum', 'Showman.wav', '[Showman]'],
#  ['S15_hum_1_Showman.wav', 'S15', 'hum', 'Showman.wav', '[Showman]'],
#  ['S34_whistle_2_Showman.wav', 'S34', 'whistle', 'Showman.wav', '[Showman]'],
#  ['S95_Hum 1 Showman.wav',
#   'S95',
#   'Hum 1 Showman.wav',
#   'Showman.wav',
#   '[Showman]'],
#  ['S52_hum_1_Showman.wav', 'S52', 'hum', 'Showman.wav', '[Showman]'],
#  ['S109_hum_1_[Showman].wav', 'S109', 'hum', 'Showman.wav', '[Showman]'],
#  ['S62_hum_4_Showman.wav', 'S62', 'hum', 'Showman.wav', '[Showman]'],
#  ['S76_whistle_2_Showman.wav', 'S76', 'whistle', 'Showman.wav', '[Showman]'],
#  ['S86_hum_4_Showman.wav', 'S86', 'hum', 'Showman.wav', '[Showman]'],
#  ['S34_hum_1_Showman.wav', 'S34', 'hum', 'Showman.wav', '[Showman]'],
#  ['S94_whistle_2_Showman.wav', 'S94', 'whistle', 'Showman.wav', '[Showman]'],
#  ['S30_hum_4_Showman.wav', 'S30', 'hum', 'Showman.wav', '[Showman]'],
#  ['S105_hum_2_this is me.wav', 'S105', 'hum', 'Showman.wav', '[Showman]'],
#  ['S46_hum_3_Showman.wav', 'S46', 'hum', 'Showman.wav', '[Showman]'],
#  ['S68_whistle_2_Showman.wav', 'S68', 'whistle', 'Showman.wav', '[Showman]'],
#  ['S20_hum_3_Showman.wav', 'S20', 'hum', 'Showman.wav', '[Showman]'],
#  ['S9_hum_4_Showman.wav', 'S9', 'hum', 'Showman.wav', '[Showman]'],
#  ['S5_hum_3_thisisme.wav', 'S5', 'hum', 'Showman.wav', '[Showman]'],
#  ['S110_hum_3_Showman.wav', 'S110', 'hum', 'Showman.wav', '[Showman]'],
#  ['S42_Hum3_Showman.wav', 'S42', 'Hum3', 'Showman.wav', '[Showman]'],
#  ['S101_hum_4_Showman.wav', 'S101', 'hum', 'Showman.wav', '[Showman]'],
#  ['S53_hum_4_Showman.wav', 'S53', 'hum', 'Showman.wav', '[Showman]'],
#  ['S52_whistle_2_Showman.wav', 'S52', 'whistle', 'Showman.wav', '[Showman]'],
#  ['S1_whistle_2_Showman.wav', 'S1', 'whistle', 'Showman.wav', '[Showman]'],
#  ['S14_hum_3_Showman.wav', 'S14', 'hum', 'Showman.wav', '[Showman]'],
#  ['S57_hum_1_Showman.wav', 'S57', 'hum', 'Showman.wav', '[Showman]'],
#  ['S44_whistle_2_Showman.wav', 'S44', 'whistle', 'Showman.wav', '[Showman]'],
#  ['S87_hum_1_Showman.wav', 'S87', 'hum', 'Showman.wav', '[Showman]'],
#  ['S10_hum_3_Showman.wav', 'S10', 'hum', 'Showman.wav', '[Showman]'],
#  ['S4_hum_3_Showman.wav', 'S4', 'hum', 'Showman.wav', '[Showman]'],
#  ['S92_Hum_3_Showman.wav', 'S92', 'Hum', 'Showman.wav', '[Showman]'],
#  ['S80_whistle_2_Showman.wav', 'S80', 'whistle', 'Showman.wav', '[Showman]'],
#  ['S24_hum_3_ShowMan.wav', 'S24', 'hum', 'Showman.wav', '[Showman]'],
#  ['S29_hum_1_Showman.wav', 'S29', 'hum', 'Showman.wav', '[Showman]'],
#  ['S95_Whistle 2 Showman.wav',
#   'S95',
#   'Whistle 2 Showman.wav',
#   'Showman.wav',
#   '[Showman]'],
#  ['S67_hum_1_Showman.wav', 'S67', 'hum', 'Showman.wav', '[Showman]'],
#  ['S47_hum_3_showman.wav', 'S47', 'hum', 'Showman.wav', '[Showman]'],
#  ['S21_hum_3_Showman.wav', 'S21', 'hum', 'Showman.wav', '[Showman]'],
#  ['S104_Hum_4_Showman.wav', 'S104', 'Hum', 'Showman.wav', '[Showman]'],
#  ['S38_hum_3_Showman.wav', 'S38', 'hum', 'Showman.wav', '[Showman]'],
#  ['S19_hum_4_Showman.wav', 'S19', 'hum', 'Showman.wav', '[Showman]'],
#  ['S31_hum_4_Showman.wav', 'S31', 'hum', 'Showman.wav', '[Showman]'],
#  ['S114_hum_3_showman.wav', 'S114', 'hum', 'Showman.wav', '[Showman]'],
#  ['S69_hum_3_Showman.wav', 'S69', 'hum', 'Showman.wav', '[Showman]'],
#  ['S73_hum_3_Showman.wav', 'S73', 'hum', 'Showman.wav', '[Showman]'],
#  ['S102_whistle_2_Showman.wav', 'S102', 'whistle', 'Showman.wav', '[Showman]'],
#  ['S18_Hum_1_Showman.wav', 'S18', 'Hum', 'Showman.wav', '[Showman]'],
#  ['S56_hum_1_Showman.wav', 'S56', 'hum', 'Showman.wav', '[Showman]'],
#  ['S111_hum_3_Showman.wav', 'S111', 'hum', 'Showman.wav', '[Showman]'],
#  ['S97_hum_3_Showman.wav', 'S97', 'hum', 'Showman.wav', '[Showman]'],
#  ['S28_hum_4_Showman.wav', 'S28', 'hum', 'Showman.wav', '[Showman]'],
#  ['S109_hum_2_[Showman].wav', 'S109', 'hum', 'Showman.wav', '[Showman]'],
#  ['S84_hum_4_Showman.wav', 'S84', 'hum', 'Showman.wav', '[Showman]'],
#  ['S56_whistle_2_Showman.wav', 'S56', 'whistle', 'Showman.wav', '[Showman]'],
#  ['S80_hum_1_Showman.wav', 'S80', 'hum', 'Showman.wav', '[Showman]'],
#  ['S40_whistle_2_showman.wav', 'S40', 'whistle', 'Showman.wav', '[Showman]'],
#  ['S13_hum_3_Showman.wav', 'S13', 'hum', 'Showman.wav', '[Showman]'],
#  ['S7_hum_3_Showman.wav', 'S7', 'hum', 'Showman.wav', '[Showman]'],
#  ['S41_hum_3_Showman.wav', 'S41', 'hum', 'Showman.wav', '[Showman]'],
#  ['S105_hum_1_this is me.wav', 'S105', 'hum', 'Showman.wav', '[Showman]'],
#  ['S64_hum_1_Showman.wav', 'S64', 'hum', 'Showman.wav', '[Showman]'],
#  ['S70_hum_3_Showman.wav', 'S70', 'hum', 'Showman.wav', '[Showman]'],
#  ['S58_hum_3_Showman.wav', 'S58', 'hum', 'Showman.wav', '[Showman]'],
#  ['S49_hum_2_[ Showman ].wav', 'S49', 'hum', 'Showman.wav', '[Showman]'],
#  ['S72_whistle_2_Showman.wav', 'S72', 'whistle', 'Showman.wav', '[Showman]'],
#  ['S103_hum_1_Showman.wav', 'S103', 'hum', 'Showman.wav', '[Showman]'],
#  ['S65_hum_4_Showman.wav', 'S65', 'hum', 'Showman.wav', '[Showman]'],
#  ['S22_hum_3_Showman.wav', 'S22', 'hum', 'Showman.wav', '[Showman]'],
#  ['S64_whistle_2_Showman.wav', 'S64', 'whistle', 'Showman.wav', '[Showman]'],
#  ['S78_hum_1_Showman.wav', 'S78', 'hum', 'Showman.wav', '[Showman]'],
#  ['S16_whistle_2_Showman.wav', 'S16', 'whistle', 'Showman.wav', '[Showman]'],
#  ['S78_whistle_2_Showman.wav', 'S78', 'whistle', 'Showman.wav', '[Showman]'],
#  ['S54_whistle_2_Showman.wav', 'S54', 'whistle', 'Showman.wav', '[Showman]'],
#  ['S107_hum_1_Showman.wav', 'S107', 'hum', 'Showman.wav', '[Showman]'],
#  ['S26_hum_3_Showman.wav', 'S26', 'hum', 'Showman.wav', '[Showman]'],
#  ['S90_whistle_2_Showman.wav', 'S90', 'whistle', 'Showman.wav', '[Showman]'],
#  ['S48_Whistle_2_Showman.wav', 'S48', 'Whistle', 'Showman.wav', '[Showman]'],
#  ['S51_hum_4_Showman.wav', 'S51', 'hum', 'Showman.wav', '[Showman]'],
#  ['S102_hum_1_Showman.wav', 'S102', 'hum', 'Showman.wav', '[Showman]'],
#  ['S48_Hum_1_Showman.wav', 'S48', 'Hum', 'Showman.wav', '[Showman]'],
#  ['S3_hum_3_Showman.wav', 'S3', 'hum', 'Showman.wav', '[Showman]'],
#  ['S23_hum_3_Showman.wav', 'S23', 'hum', 'Showman.wav', '[Showman]'],
#  ['S32_whistle_2_Showman.wav', 'S32', 'whistle', 'Showman.wav', '[Showman]'],
#  ['S85_hum_4_Showman.wav', 'S85', 'hum', 'Showman.wav', '[Showman]'],
#  ['S74_hum_3_Showman.wav', 'S74', 'hum', 'Showman.wav', '[Showman]'],
#  ['S12_hum_3_Showman.wav', 'S12', 'hum', 'Showman.wav', '[Showman]'],
#  ['S54_hum_1_Showman.wav', 'S54', 'hum', 'Showman.wav', '[Showman]'],
#  ['S59_hum_3_Showman.wav', 'S59', 'hum', 'Showman.wav', '[Showman]'],
#  ['S17_hum_3_Showman.wav', 'S17', 'hum', 'Showman.wav', '[Showman]'],
#  ['S36_hum_4_Showman.wav', 'S36', 'hum', 'Showman.wav', '[Showman]'],
#  ['S66_whistle_2_Showman.wav', 'S66', 'whistle', 'Showman.wav', '[Showman]'],
#  ['S32_hum_1_Showman.wav', 'S32', 'hum', 'Showman.wav', '[Showman]'],
#  ['S71_hum_3_Showman.wav', 'S71', 'hum', 'Showman.wav', '[Showman]']]

# %%
show_df = pd.DataFrame(show_table,columns=['file_id','participant','interpretation','number','song']).set_index('file_id') 
show_df
# Out:
#                           participant interpretation number     song
# file_id
# S99_hum_1_[Showman].wav           S99            hum    S99      hum
# S36_hum_3_Showman.wav             S36            hum    S36      hum
# S75_hum_1_Showman.wav             S75            hum    S75      hum
# S3_hum_4_Showman.wav               S3            hum     S3      hum
# S23_hum_4_Showman.wav             S23            hum    S23      hum
# ...                               ...            ...    ...      ...
# S17_hum_3_Showman.wav             S17            hum    S17      hum
# S36_hum_4_Showman.wav             S36            hum    S36      hum
# S66_whistle_2_Showman.wav         S66        whistle    S66  whistle
# S32_hum_1_Showman.wav             S32            hum    S32      hum
# S71_hum_3_Showman.wav             S71            hum    S71      hum
#
# [207 rows x 4 columns]

# %%
path1 = '/content/drive/MyDrive/Data/Mamma_1'
os.listdir(path1)
# Out:
# ['S79_hum_3_[Mamma].wav',
#  'S5_hum_4_mummamia.wav',
#  'S91_hum_2_Mamma.wav',
#  'S5_hum_3_mummamia.wav',
#  'S76_whistle_2_Mamma.wav',
#  'S69_hum_2_Mamma.wav',
#  'S3_hum_2_Mamma.wav',
#  'S29_whistle_2_[Mamma].wav',
#  'S54_hum_2_Mamma.wav',
#  'S77_whistle_2_Mamma.wav',
#  'S70_hum_2_Mamma.wav',
#  'S87_hum_2_Mamma.wav',
#  'S21_hum_2_Mamma.wav',
#  'S42_Hum1_Mamma.wav',
#  'S75_whistle_2_Mamma.wav',
#  'S28_hum_3_Mamma.wav',
#  'S66_hum_2_Mamma.wav',
#  'S13_hum_2_Mamma.wav',
#  'S97_hum_3_Mamma.wav',
#  'S31_hum_3_Mamma.wav',
#  'S6_whisle_1_Mamma.wav',
#  'S61_whistle_1_[Mama].wav',
#  'S87_whistle_2_Mamma.wav',
#  'S37_whistle_2_[Mamma].wav',
#  'S38_hum_2_Mamma.wav',
#  'S71_hum_3_Mamma.wav',
#  'S104_Hum_3_Mamma.wav',
#  'S36_hum_3_Mamma.wav',
#  'S72_whistle_2_Mamma.wav',
#  'S78_hum_2_Mamma.wav',
#  'S45_hum_2_Mamma.wav',
#  'S14_hum_2_Mamma.wav',
#  'S12_hum_3_Mamma.wav',
#  'S80_whistle_2_Mamma.wav',
#  'S26_hum_2_Mamma.wav',
#  'S80_hum_2_Mamma.wav',
#  'S114_hum_2_mamma.wav',
#  'S102_hum_2_Mamma.wav',
#  'S68_whistle_2_Mamma.wav',
#  'S39_whistle_2_Mamma.wav',
#  'S77_hum_2_Mamma.wav',
#  'S53_hum_2_Mamma.wav',
#  'S86_hum_3_Mamma.wav',
#  'S20_hum_3_Mamma.wav',
#  'S88_hum_1_[Mamma].wav',
#  'S44_hum_2_Mamma.wav',
#  'S70_hum_3_Mamma.wav',
#  'S95_Whistle 1 Mamma.wav',
#  'S30_hum_2_Mamma.wav',
#  'S4_hum_2_Mumma.wav',
#  'S64_whistle_2_Mamma.wav',
#  'S115_hum_2_Mamma.wav',
#  'S13_hum_3_Mamma.wav',
#  'S34_whistle_2_Mamma.wav',
#  'S35_hum_3_[Mamma].wav',
#  'S94_whistle_2_Mamma.wav',
#  'S52_hum_2_Mamma.wav',
#  'S67_whistle_2_Mamma.wav',
#  'S21_hum_3_Mamma.wav',
#  'S69_hum_3_Mamma.wav',
#  'S97_hum_2_Mamma.wav',
#  'S31_hum_2_Mamma.wav',
#  'S103_hum_2_Mamma.wav',
#  'S15_hum_2_Mamma.wav',
#  'S28_hum_2_Mamma.wav',
#  'S82_hum_3_[Mamma].wav',
#  'S93_whistle_2_Mamma.wav',
#  'S71_hum_2_Mamma.wav',
#  'S76_hum_2_Mamma.wav',
#  'S38_hum_3_Mamma.wav',
#  'S66_whistle_2_Mamma.wav',
#  'S12_hum_2_Mamma.wav',
#  'S104_Hum_2_Mamma.wav',
#  'S36_hum_2_Mamma.wav',
#  'S1_whistle_2_Mamma.wav',
#  'S90_hum_2_Mamma.wav',
#  'S61_hum_1_[Mama].wav',
#  'S2_hum_2_Mamma.wav',
#  'S8_hum_3_[Mamma].wav',
#  'S78_whistle_2_Mamma.wav',
#  'S114_hum_3_mamma.wav',
#  'S89_hum_2_Mamma.wav',
#  'S53_hum_3_Mamma.wav',
#  'S86_hum_2_Mamma.wav',
#  'S20_hum_2_Mamma.wav',
#  'S68_hum_2_Mamma.wav',
#  'S109_hum_1_[Mamma].wav',
#  'S26_hum_3_Mamma.wav',
#  'S2_whistle_2_Mamma.wav',
#  'S63_hum_3_[Mamma].wav',
#  'S91_whistle_2_Mamma.wav',
#  'S14_hum_3_Mamma.wav',
#  'S67_hum_2_Mamma.wav',
#  'S3_whistle_2_Mamma.wav',
#  'S99_whistle_2_[Mamma].wav',
#  'S90_whistle_2_Mamma.wav',
#  'S89_whistle_2_Mamma.wav',
#  'S43_hum_2_Mamma.wav',
#  'S4_hum_3_Mumma.wav',
#  'S30_hum_3_Mamma.wav',
#  'S117_hum_2_Mamma.wav',
#  'S35_hum_1_[Mamma].wav',
#  'S62_hum_2_Mamma.wav',
#  'S115_whistle_2_Mamma.wav',
#  'S39_hum_2_Mamma.wav',
#  'S32_whistle_2_Mamma.wav',
#  'S101_hum_2_Mamma.wav',
#  'S52_whistle_2_Mamma.wav',
#  'S105_whistle_1_mamamia.wav',
#  'S29_hum_1_[Mamma].wav',
#  'S46_hum_2_Mamma.wav',
#  'S18_Hum_2_Mamma.wav',
#  'S25_hum_2_Mamma.wav',
#  'S85_hum_3_Mamma.wav',
#  'S88_whistle_2_[Mamma].wav',
#  'S117_whistle_2_Mamma.wav',
#  'S74_hum_2_Mamma.wav',
#  'S48_Whistle_2_Mamma.wav',
#  'S120_whistle_1_Mamma.wav',
#  'S17_hum_2_Mamma.wav',
#  'S59_hum_3_Mamma.wav',
#  'S111_hum_3_Mamma.wav',
#  'S23_hum_3_Mamma.wav',
#  'S7_hum_2_Mamma.wav',
#  'S116_hum_3_Mamma.wav',
#  'S9_hum_3_Mamma.wav',
#  'S10_hum_2_Mamma.wav',
#  'S118_hum_2_Mamma.wav',
#  'S18_Whistle_2_Mamma.wav',
#  'S57_hum_2_Mamma.wav',
#  'S82_hum_1_[Mamma].wav',
#  'S55_mamia_whistle_2.wav',
#  'S19_hum_3_Mamma.wav',
#  'S24_hum_3_Mamma.wav',
#  'S8_hum_1_[Mamma].wav',
#  'S109_hum_3_[Mamma].wav',
#  'S57_whistle_2_Mamma.wav',
#  'S56_whistle_2_Mumma.wav',
#  'S73_hum_2_Mamma.wav',
#  'S106_hum_2_Mamma.WAV',
#  'S92_Hum_2_Mamma.wav',
#  'S34_hum_2_Mamma.wav',
#  'S108_whistle_2_Mamma.wav',
#  'S55_mamia_whistle_1.wav',
#  'S54_whistle_2_Mamma.wav',
#  'S41_hum_2_Mamma.wav',
#  'S100_hum_3_Mamma.wav',
#  'S60_whistle_2_[Mamma].wav',
#  'S110_hum_2_Mamma.wav',
#  'S22_hum_2_Mamma.wav',
#  'S84_hum_2_Mamma.wav',
#  'S51_hum_3_Mamma.wav',
#  'S119_hum_3_Mamma.wav',
#  'S65_hum_2_Mamma.wav',
#  'S58_hum_2_Mamma.wav',
#  'S25_hum_3_Mamma.wav',
#  'S37_hum_1_[Mamma].wav',
#  'S107_whistle_2_Mamma.wav',
#  'S63_hum_1_[Mamma].wav',
#  'S56_hum_2_Mumma.wav',
#  'S62_hum_3_Mamma.wav',
#  'S1_hum_2_Mamma.wav',
#  'S79_hum_1_[mamma].wav',
#  'S72_hum_2_Mamma.wav',
#  'S107_hum_2_Mamma.wav',
#  'S46_hum_3_Mamma.wav',
#  'S93_hum_2_Mamma.wav',
#  'S74_hum_3_Mamma.wav',
#  'S43_whistle_2_Mamma.wav',
#  'S47_hum_1_mamamia.wav',
#  'S108_hum_2_Mamma.wav',
#  'S40_whistle_2_mamma.wav',
#  'S7_hum_3_Mamma.wav',
#  'S118_hum_3_Mamma.wav',
#  'S64_hum_2_Mamma.wav',
#  'S17_hum_3_Mamma.wav',
#  'S59_hum_2_Mamma.wav',
#  'S40_hum_2_mamma.wav',
#  'S101_hum_3_Mamma.wav',
#  'S60_hum_1_[Mamma].wav',
#  'S111_hum_2_Mamma.wav',
#  'S42_Hum2_Mamma.wav',
#  'S23_hum_2_Mamma.wav',
#  'S49_hum_4_[ Mamma ].wav',
#  'S85_hum_2_Mamma.wav',
#  'S116_hum_2_Mamma.wav',
#  'S15_whistle_2_Mamma.wav',
#  'S19_hum_2_Mamma.wav',
#  'S44_whistle_2_Mamma.wav',
#  'S24_hum_2_Mamma.wav',
#  'S9_hum_2_Mamma.wav',
#  'S102_whistle_2_Mamma.wav',
#  'S47_hum_4_mamamia.wav',
#  'S49_hum_3_[ Mamma ].wav',
#  'S92_Hum_3_Mamma.wav',
#  'S45_whistle_2_Mamma.wav',
#  'S10_hum_3_Mamma.wav',
#  'S48_Hum_2_Mamma.wav',
#  'S103_whistle_2_Mamma.wav',
#  'S73_hum_3_Mamma.wav',
#  'S106_hum_3_Mamma.WAV',
#  'S105_whistle_2_mamamia.wav',
#  'S75_hum_2_Mamma.wav',
#  'S95_Hum 1 Mamma.wav',
#  'S94_hum_2_Mamma.wav',
#  'S41_hum_3_Mamma.wav',
#  'S100_hum_2_Mamma.wav',
#  'S65_hum_3_Mamma.wav',
#  'S16_hum_2_Mamma.wav',
#  'S58_hum_3_Mamma.wav',
#  'S32_hum_2_Mamma.wav',
#  'S84_hum_3_Mamma.wav',
#  'S51_hum_2_Mamma.wav',
#  'S6_hum_2_Mamma.wav',
#  'S119_hum_2_Mamma.wav',
#  'S99_hum_1_[Mamma].wav',
#  'S110_hum_3_Mamma.wav',
#  'S16_whistle_2_Mamma.wav',
#  'S22_hum_3_Mamma.wav']

# %%
sample_path1 = '/content/drive/MyDrive/Data/Mamma_1/*.wav'
files_mamma = glob.glob(sample_path1)
len(files_mamma)
for _ in range(5):
  n1 = np.random.randint(210)
  display(ipd.Audio(files_mamma[n1]))
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
mam_table = [] 

for file in files_mamma:
  file_name = file.split('/')[-1]
  participant_ID = file.split('/')[-1].split('_')[0]
  interpretation_type = file.split('/')[-1].split('_')[1]
  #interpretation_number = file.split('/')[-1].split('_')[2]
  #song = file.split('/')[-1].split('_')[3].split('.')[0]
  mam_table.append([file_name,participant_ID,interpretation_type,interpretation_number, song])

mam_table
# Out:
# [['S79_hum_3_[Mamma].wav', 'S79', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S5_hum_4_mummamia.wav', 'S5', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S91_hum_2_Mamma.wav', 'S91', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S5_hum_3_mummamia.wav', 'S5', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S76_whistle_2_Mamma.wav', 'S76', 'whistle', 'Mamma.wav', 'Mamma'],
#  ['S69_hum_2_Mamma.wav', 'S69', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S3_hum_2_Mamma.wav', 'S3', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S29_whistle_2_[Mamma].wav', 'S29', 'whistle', 'Mamma.wav', 'Mamma'],
#  ['S54_hum_2_Mamma.wav', 'S54', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S77_whistle_2_Mamma.wav', 'S77', 'whistle', 'Mamma.wav', 'Mamma'],
#  ['S70_hum_2_Mamma.wav', 'S70', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S87_hum_2_Mamma.wav', 'S87', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S21_hum_2_Mamma.wav', 'S21', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S42_Hum1_Mamma.wav', 'S42', 'Hum1', 'Mamma.wav', 'Mamma'],
#  ['S75_whistle_2_Mamma.wav', 'S75', 'whistle', 'Mamma.wav', 'Mamma'],
#  ['S28_hum_3_Mamma.wav', 'S28', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S66_hum_2_Mamma.wav', 'S66', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S13_hum_2_Mamma.wav', 'S13', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S97_hum_3_Mamma.wav', 'S97', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S31_hum_3_Mamma.wav', 'S31', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S6_whisle_1_Mamma.wav', 'S6', 'whisle', 'Mamma.wav', 'Mamma'],
#  ['S61_whistle_1_[Mama].wav', 'S61', 'whistle', 'Mamma.wav', 'Mamma'],
#  ['S87_whistle_2_Mamma.wav', 'S87', 'whistle', 'Mamma.wav', 'Mamma'],
#  ['S37_whistle_2_[Mamma].wav', 'S37', 'whistle', 'Mamma.wav', 'Mamma'],
#  ['S38_hum_2_Mamma.wav', 'S38', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S71_hum_3_Mamma.wav', 'S71', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S104_Hum_3_Mamma.wav', 'S104', 'Hum', 'Mamma.wav', 'Mamma'],
#  ['S36_hum_3_Mamma.wav', 'S36', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S72_whistle_2_Mamma.wav', 'S72', 'whistle', 'Mamma.wav', 'Mamma'],
#  ['S78_hum_2_Mamma.wav', 'S78', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S45_hum_2_Mamma.wav', 'S45', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S14_hum_2_Mamma.wav', 'S14', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S12_hum_3_Mamma.wav', 'S12', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S80_whistle_2_Mamma.wav', 'S80', 'whistle', 'Mamma.wav', 'Mamma'],
#  ['S26_hum_2_Mamma.wav', 'S26', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S80_hum_2_Mamma.wav', 'S80', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S114_hum_2_mamma.wav', 'S114', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S102_hum_2_Mamma.wav', 'S102', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S68_whistle_2_Mamma.wav', 'S68', 'whistle', 'Mamma.wav', 'Mamma'],
#  ['S39_whistle_2_Mamma.wav', 'S39', 'whistle', 'Mamma.wav', 'Mamma'],
#  ['S77_hum_2_Mamma.wav', 'S77', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S53_hum_2_Mamma.wav', 'S53', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S86_hum_3_Mamma.wav', 'S86', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S20_hum_3_Mamma.wav', 'S20', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S88_hum_1_[Mamma].wav', 'S88', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S44_hum_2_Mamma.wav', 'S44', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S70_hum_3_Mamma.wav', 'S70', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S95_Whistle 1 Mamma.wav',
#   'S95',
#   'Whistle 1 Mamma.wav',
#   'Mamma.wav',
#   'Mamma'],
#  ['S30_hum_2_Mamma.wav', 'S30', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S4_hum_2_Mumma.wav', 'S4', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S64_whistle_2_Mamma.wav', 'S64', 'whistle', 'Mamma.wav', 'Mamma'],
#  ['S115_hum_2_Mamma.wav', 'S115', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S13_hum_3_Mamma.wav', 'S13', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S34_whistle_2_Mamma.wav', 'S34', 'whistle', 'Mamma.wav', 'Mamma'],
#  ['S35_hum_3_[Mamma].wav', 'S35', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S94_whistle_2_Mamma.wav', 'S94', 'whistle', 'Mamma.wav', 'Mamma'],
#  ['S52_hum_2_Mamma.wav', 'S52', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S67_whistle_2_Mamma.wav', 'S67', 'whistle', 'Mamma.wav', 'Mamma'],
#  ['S21_hum_3_Mamma.wav', 'S21', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S69_hum_3_Mamma.wav', 'S69', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S97_hum_2_Mamma.wav', 'S97', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S31_hum_2_Mamma.wav', 'S31', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S103_hum_2_Mamma.wav', 'S103', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S15_hum_2_Mamma.wav', 'S15', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S28_hum_2_Mamma.wav', 'S28', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S82_hum_3_[Mamma].wav', 'S82', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S93_whistle_2_Mamma.wav', 'S93', 'whistle', 'Mamma.wav', 'Mamma'],
#  ['S71_hum_2_Mamma.wav', 'S71', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S76_hum_2_Mamma.wav', 'S76', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S38_hum_3_Mamma.wav', 'S38', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S66_whistle_2_Mamma.wav', 'S66', 'whistle', 'Mamma.wav', 'Mamma'],
#  ['S12_hum_2_Mamma.wav', 'S12', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S104_Hum_2_Mamma.wav', 'S104', 'Hum', 'Mamma.wav', 'Mamma'],
#  ['S36_hum_2_Mamma.wav', 'S36', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S1_whistle_2_Mamma.wav', 'S1', 'whistle', 'Mamma.wav', 'Mamma'],
#  ['S90_hum_2_Mamma.wav', 'S90', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S61_hum_1_[Mama].wav', 'S61', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S2_hum_2_Mamma.wav', 'S2', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S8_hum_3_[Mamma].wav', 'S8', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S78_whistle_2_Mamma.wav', 'S78', 'whistle', 'Mamma.wav', 'Mamma'],
#  ['S114_hum_3_mamma.wav', 'S114', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S89_hum_2_Mamma.wav', 'S89', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S53_hum_3_Mamma.wav', 'S53', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S86_hum_2_Mamma.wav', 'S86', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S20_hum_2_Mamma.wav', 'S20', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S68_hum_2_Mamma.wav', 'S68', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S109_hum_1_[Mamma].wav', 'S109', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S26_hum_3_Mamma.wav', 'S26', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S2_whistle_2_Mamma.wav', 'S2', 'whistle', 'Mamma.wav', 'Mamma'],
#  ['S63_hum_3_[Mamma].wav', 'S63', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S91_whistle_2_Mamma.wav', 'S91', 'whistle', 'Mamma.wav', 'Mamma'],
#  ['S14_hum_3_Mamma.wav', 'S14', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S67_hum_2_Mamma.wav', 'S67', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S3_whistle_2_Mamma.wav', 'S3', 'whistle', 'Mamma.wav', 'Mamma'],
#  ['S99_whistle_2_[Mamma].wav', 'S99', 'whistle', 'Mamma.wav', 'Mamma'],
#  ['S90_whistle_2_Mamma.wav', 'S90', 'whistle', 'Mamma.wav', 'Mamma'],
#  ['S89_whistle_2_Mamma.wav', 'S89', 'whistle', 'Mamma.wav', 'Mamma'],
#  ['S43_hum_2_Mamma.wav', 'S43', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S4_hum_3_Mumma.wav', 'S4', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S30_hum_3_Mamma.wav', 'S30', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S117_hum_2_Mamma.wav', 'S117', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S35_hum_1_[Mamma].wav', 'S35', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S62_hum_2_Mamma.wav', 'S62', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S115_whistle_2_Mamma.wav', 'S115', 'whistle', 'Mamma.wav', 'Mamma'],
#  ['S39_hum_2_Mamma.wav', 'S39', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S32_whistle_2_Mamma.wav', 'S32', 'whistle', 'Mamma.wav', 'Mamma'],
#  ['S101_hum_2_Mamma.wav', 'S101', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S52_whistle_2_Mamma.wav', 'S52', 'whistle', 'Mamma.wav', 'Mamma'],
#  ['S105_whistle_1_mamamia.wav', 'S105', 'whistle', 'Mamma.wav', 'Mamma'],
#  ['S29_hum_1_[Mamma].wav', 'S29', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S46_hum_2_Mamma.wav', 'S46', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S18_Hum_2_Mamma.wav', 'S18', 'Hum', 'Mamma.wav', 'Mamma'],
#  ['S25_hum_2_Mamma.wav', 'S25', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S85_hum_3_Mamma.wav', 'S85', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S88_whistle_2_[Mamma].wav', 'S88', 'whistle', 'Mamma.wav', 'Mamma'],
#  ['S117_whistle_2_Mamma.wav', 'S117', 'whistle', 'Mamma.wav', 'Mamma'],
#  ['S74_hum_2_Mamma.wav', 'S74', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S48_Whistle_2_Mamma.wav', 'S48', 'Whistle', 'Mamma.wav', 'Mamma'],
#  ['S120_whistle_1_Mamma.wav', 'S120', 'whistle', 'Mamma.wav', 'Mamma'],
#  ['S17_hum_2_Mamma.wav', 'S17', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S59_hum_3_Mamma.wav', 'S59', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S111_hum_3_Mamma.wav', 'S111', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S23_hum_3_Mamma.wav', 'S23', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S7_hum_2_Mamma.wav', 'S7', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S116_hum_3_Mamma.wav', 'S116', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S9_hum_3_Mamma.wav', 'S9', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S10_hum_2_Mamma.wav', 'S10', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S118_hum_2_Mamma.wav', 'S118', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S18_Whistle_2_Mamma.wav', 'S18', 'Whistle', 'Mamma.wav', 'Mamma'],
#  ['S57_hum_2_Mamma.wav', 'S57', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S82_hum_1_[Mamma].wav', 'S82', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S55_mamia_whistle_2.wav', 'S55', 'mamia', 'Mamma.wav', 'Mamma'],
#  ['S19_hum_3_Mamma.wav', 'S19', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S24_hum_3_Mamma.wav', 'S24', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S8_hum_1_[Mamma].wav', 'S8', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S109_hum_3_[Mamma].wav', 'S109', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S57_whistle_2_Mamma.wav', 'S57', 'whistle', 'Mamma.wav', 'Mamma'],
#  ['S56_whistle_2_Mumma.wav', 'S56', 'whistle', 'Mamma.wav', 'Mamma'],
#  ['S73_hum_2_Mamma.wav', 'S73', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S92_Hum_2_Mamma.wav', 'S92', 'Hum', 'Mamma.wav', 'Mamma'],
#  ['S34_hum_2_Mamma.wav', 'S34', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S108_whistle_2_Mamma.wav', 'S108', 'whistle', 'Mamma.wav', 'Mamma'],
#  ['S55_mamia_whistle_1.wav', 'S55', 'mamia', 'Mamma.wav', 'Mamma'],
#  ['S54_whistle_2_Mamma.wav', 'S54', 'whistle', 'Mamma.wav', 'Mamma'],
#  ['S41_hum_2_Mamma.wav', 'S41', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S100_hum_3_Mamma.wav', 'S100', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S60_whistle_2_[Mamma].wav', 'S60', 'whistle', 'Mamma.wav', 'Mamma'],
#  ['S110_hum_2_Mamma.wav', 'S110', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S22_hum_2_Mamma.wav', 'S22', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S84_hum_2_Mamma.wav', 'S84', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S51_hum_3_Mamma.wav', 'S51', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S119_hum_3_Mamma.wav', 'S119', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S65_hum_2_Mamma.wav', 'S65', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S58_hum_2_Mamma.wav', 'S58', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S25_hum_3_Mamma.wav', 'S25', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S37_hum_1_[Mamma].wav', 'S37', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S107_whistle_2_Mamma.wav', 'S107', 'whistle', 'Mamma.wav', 'Mamma'],
#  ['S63_hum_1_[Mamma].wav', 'S63', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S56_hum_2_Mumma.wav', 'S56', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S62_hum_3_Mamma.wav', 'S62', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S1_hum_2_Mamma.wav', 'S1', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S79_hum_1_[mamma].wav', 'S79', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S72_hum_2_Mamma.wav', 'S72', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S107_hum_2_Mamma.wav', 'S107', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S46_hum_3_Mamma.wav', 'S46', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S93_hum_2_Mamma.wav', 'S93', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S74_hum_3_Mamma.wav', 'S74', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S43_whistle_2_Mamma.wav', 'S43', 'whistle', 'Mamma.wav', 'Mamma'],
#  ['S47_hum_1_mamamia.wav', 'S47', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S108_hum_2_Mamma.wav', 'S108', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S40_whistle_2_mamma.wav', 'S40', 'whistle', 'Mamma.wav', 'Mamma'],
#  ['S7_hum_3_Mamma.wav', 'S7', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S118_hum_3_Mamma.wav', 'S118', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S64_hum_2_Mamma.wav', 'S64', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S17_hum_3_Mamma.wav', 'S17', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S59_hum_2_Mamma.wav', 'S59', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S40_hum_2_mamma.wav', 'S40', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S101_hum_3_Mamma.wav', 'S101', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S60_hum_1_[Mamma].wav', 'S60', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S111_hum_2_Mamma.wav', 'S111', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S42_Hum2_Mamma.wav', 'S42', 'Hum2', 'Mamma.wav', 'Mamma'],
#  ['S23_hum_2_Mamma.wav', 'S23', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S49_hum_4_[ Mamma ].wav', 'S49', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S85_hum_2_Mamma.wav', 'S85', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S116_hum_2_Mamma.wav', 'S116', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S15_whistle_2_Mamma.wav', 'S15', 'whistle', 'Mamma.wav', 'Mamma'],
#  ['S19_hum_2_Mamma.wav', 'S19', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S44_whistle_2_Mamma.wav', 'S44', 'whistle', 'Mamma.wav', 'Mamma'],
#  ['S24_hum_2_Mamma.wav', 'S24', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S9_hum_2_Mamma.wav', 'S9', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S102_whistle_2_Mamma.wav', 'S102', 'whistle', 'Mamma.wav', 'Mamma'],
#  ['S47_hum_4_mamamia.wav', 'S47', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S49_hum_3_[ Mamma ].wav', 'S49', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S92_Hum_3_Mamma.wav', 'S92', 'Hum', 'Mamma.wav', 'Mamma'],
#  ['S45_whistle_2_Mamma.wav', 'S45', 'whistle', 'Mamma.wav', 'Mamma'],
#  ['S10_hum_3_Mamma.wav', 'S10', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S48_Hum_2_Mamma.wav', 'S48', 'Hum', 'Mamma.wav', 'Mamma'],
#  ['S103_whistle_2_Mamma.wav', 'S103', 'whistle', 'Mamma.wav', 'Mamma'],
#  ['S73_hum_3_Mamma.wav', 'S73', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S105_whistle_2_mamamia.wav', 'S105', 'whistle', 'Mamma.wav', 'Mamma'],
#  ['S75_hum_2_Mamma.wav', 'S75', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S95_Hum 1 Mamma.wav', 'S95', 'Hum 1 Mamma.wav', 'Mamma.wav', 'Mamma'],
#  ['S94_hum_2_Mamma.wav', 'S94', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S41_hum_3_Mamma.wav', 'S41', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S100_hum_2_Mamma.wav', 'S100', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S65_hum_3_Mamma.wav', 'S65', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S16_hum_2_Mamma.wav', 'S16', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S58_hum_3_Mamma.wav', 'S58', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S32_hum_2_Mamma.wav', 'S32', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S84_hum_3_Mamma.wav', 'S84', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S51_hum_2_Mamma.wav', 'S51', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S6_hum_2_Mamma.wav', 'S6', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S119_hum_2_Mamma.wav', 'S119', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S99_hum_1_[Mamma].wav', 'S99', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S110_hum_3_Mamma.wav', 'S110', 'hum', 'Mamma.wav', 'Mamma'],
#  ['S16_whistle_2_Mamma.wav', 'S16', 'whistle', 'Mamma.wav', 'Mamma'],
#  ['S22_hum_3_Mamma.wav', 'S22', 'hum', 'Mamma.wav', 'Mamma']]

# %%
mam_df = pd.DataFrame(mam_table,columns=['file_id','participant','interpretation','number','song']).set_index('file_id') 
mam_df
# Out:
#                         participant interpretation     number   song
# file_id
# S79_hum_3_[Mamma].wav           S79            hum  Mamma.wav  Mamma
# S5_hum_4_mummamia.wav            S5            hum  Mamma.wav  Mamma
# S91_hum_2_Mamma.wav             S91            hum  Mamma.wav  Mamma
# S5_hum_3_mummamia.wav            S5            hum  Mamma.wav  Mamma
# S76_whistle_2_Mamma.wav         S76        whistle  Mamma.wav  Mamma
# ...                             ...            ...        ...    ...
# S119_hum_2_Mamma.wav           S119            hum  Mamma.wav  Mamma
# S99_hum_1_[Mamma].wav           S99            hum  Mamma.wav  Mamma
# S110_hum_3_Mamma.wav           S110            hum  Mamma.wav  Mamma
# S16_whistle_2_Mamma.wav         S16        whistle  Mamma.wav  Mamma
# S22_hum_3_Mamma.wav             S22            hum  Mamma.wav  Mamma
#
# [217 rows x 4 columns]

# %%
MLENDHWdf = pd.concat([mam_df,show_df])
MLENDHWdf
# Out:
#                           participant interpretation     number     song
# file_id
# S79_hum_3_[Mamma].wav             S79            hum  Mamma.wav    Mamma
# S5_hum_4_mummamia.wav              S5            hum  Mamma.wav    Mamma
# S91_hum_2_Mamma.wav               S91            hum  Mamma.wav    Mamma
# S5_hum_3_mummamia.wav              S5            hum  Mamma.wav    Mamma
# S76_whistle_2_Mamma.wav           S76        whistle  Mamma.wav    Mamma
# ...                               ...            ...        ...      ...
# S17_hum_3_Showman.wav             S17            hum        S17      hum
# S36_hum_4_Showman.wav             S36            hum        S36      hum
# S66_whistle_2_Showman.wav         S66        whistle        S66  whistle
# S32_hum_1_Showman.wav             S32            hum        S32      hum
# S71_hum_3_Showman.wav             S71            hum        S71      hum
#
# [424 rows x 4 columns]

# %%
files = files_showman + files_mamma

# %%
n=0
fs = None 
x, fs = librosa.load(files[n],sr=fs)
t = np.arange(len(x))/fs
plt.plot(t,x)
plt.xlabel('time (sec)')
plt.ylabel('amplitude')
plt.show()
display(ipd.Audio(files[n]))

n=0
x, fs = librosa.load(files[n],sr=fs)
print('This audio signal has', len(x), 'samples')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # 8 Results
#
# **Carry out your experiments here, explain your results.**

# %%
def getPitch(x,fs,winLen=0.02):
  #winLen = 0.02 
  p = winLen*fs
  frame_length = int(2**int(p-1).bit_length())
  hop_length = frame_length//2
  f0, voiced_flag, voiced_probs = librosa.pyin(y=x, fmin=80, fmax=450, sr=fs,
                                                 frame_length=frame_length,hop_length=hop_length)
  return f0,voiced_flag

def getXy(files,labels_file, scale_audio=False, onlySingleDigit=False):
  X,y =[],[]
  for file in tqdm(files):
    fileID = file.split('/')[-1]
    file_name = file.split('/')[-1]
    #print(file_name)
    #print(labels_file.loc[fileID]['interpretation'])
    #print(labels_file.loc[fileID]['interpretation']=='hum')
    #yi = list(labels_file.loc[fileID]['interpretation'])[0]=='hum'
    yi = labels_file.loc[fileID]['song']=='Mamma'

    fs = None # if None, fs would be 22050
    x, fs = librosa.load(file,sr=fs)
    if scale_audio: x = x/np.max(np.abs(x))
    f0, voiced_flag = getPitch(x,fs,winLen=0.02)
      
    power = np.sum(x**2)/len(x)
    pitch_mean = np.nanmean(f0) if np.mean(np.isnan(f0))<1 else 0
    pitch_std  = np.nanstd(f0) if np.mean(np.isnan(f0))<1 else 0
    voiced_fr = np.mean(voiced_flag)

    xi = [power,pitch_mean,pitch_std,voiced_fr]
    X.append(xi)
    y.append(yi)
    
  return np.array(X),np.array(y)

# %%
X,y = getXy(files, labels_file= MLENDHWdf, scale_audio=True, onlySingleDigit=True)
# Out:
# 100%|██████████| 424/424 [20:31<00:00,  2.90s/it]

# %%
print('The shape of X is', X.shape) 
print('The shape of y is', y.shape)
print('The labels vector is', y)
# Out:
# The shape of X is (424, 4)
# The shape of y is (424,)
# The labels vector is [False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True]

# %%
print(' The number of hum recordings is ', np.count_nonzero(y))
print(' The number of whistle recordings is ', y.size - np.count_nonzero(y))
# Out:
#  The number of hum recordings is  217
#  The number of whistle recordings is  207

# %%
from sklearn import svm
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(X,y,test_size=0.3)
X_train.shape, X_val.shape, y_train.shape, y_val.shape
# Out:
# ((296, 4), (128, 4), (296,), (128,))

# %%
model  = svm.SVC(C=1)
model.fit (X_train,y_train)

yt_p = model.predict(X_train)
yv_p = model.predict(X_val)

print('Training Accuracy', np.mean(yt_p==y_train))
print('Validation  Accuracy', np.mean(yv_p==y_val))
print('The support vectors are', model.support_vectors_.shape)
# Out:
# Training Accuracy 0.5540540540540541
# Validation  Accuracy 0.4765625
# The support vectors are (276, 4)

# %% [markdown]
# Looking at the results produced it can be concluded that the label of the audio file can be identified using this model from the initial raw audio files.The feature extraction (Pitch) that was used allowed the model to determine whether or not the audio file was labelled Mamma by providing a True or False response. The accuracy of the training set produced a value of 0.55 and the accuracy of the validation set produced a value of 0.48 . This would indicate that the model fits well. However, the accuracy for both the training and validation sets were quite low, which could mean that the model might not have been able to identify some of the audio files correctly based on their pitch.

# %% [markdown]
# # 9 Conclusions
#
# In conclusion, this mini-project showed that using specific feature extractions such as pitch, machine learning problems that require classifications can be distinguished using models such as SVM.
